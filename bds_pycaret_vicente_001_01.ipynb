# %% [markdown]
# <a href="https://colab.research.google.com/github/Viny2030/UMSA-Analisis_de_datos/blob/main/bds_pycaret_vicente_001_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center">
# <img src="https://github.com/cristiandarioortegayubro/BA/blob/main/PyCaret.png?raw=true" width="270" height="">
# </p>

# %% [markdown]
# <p align="justify"><b>
# <font color="DeepPink">
# 💗 Todo el mundo deberia aprender a programar, porque te enseña a pensar...
# </font>
# </p>
# <p align="right"><b>
# <font color="DeepPink">
# Steve Jobs (1995)
# </font>
# </p>
# <br>
# <br>

# %% [markdown]
#  # **<font color="DeepPink">PyCaret - Clasificación</font>**

# %% [markdown]
# <p align="justify">
# En <code>PyCaret</code>, el módulo de Clasificación (Classification Module) es una parte integral de la biblioteca diseñada para realizar tareas de clasificación automatizada. La clasificación es un tipo de problema de aprendizaje automático supervisado en el que el objetivo es predecir la clase o categoría de un elemento basándose en sus características (atributos).
# <br>
# <br>
# El módulo de Clasificación de <code>PyCaret</code> ofrece una serie de funciones y herramientas que facilitan el proceso de construcción, entrenamiento y evaluación de modelos de clasificación de manera automatizada y eficiente.
# <br>
# <br>
# Algunas de las características clave del módulo de Clasificación de PyCaret son:
# <br>
# <br>
# <ol align="justify">
# <li><b>Preprocesamiento de datos</b>: <code>PyCaret</code> automatiza el preprocesamiento de datos, lo que incluye el manejo de valores faltantes, codificación de variables categóricas, división de datos en conjuntos de entrenamiento y prueba, y más. Esto permite a los usuarios centrarse más en el desarrollo del modelo en sí y menos en las tareas de limpieza y transformación de datos.</li>
# <br>
# <li><b>Comparación de modelos</b>: <code>PyCaret</code> permite a los usuarios comparar fácilmente varios modelos de clasificación populares. La biblioteca entrena automáticamente múltiples modelos en el conjunto de datos y proporciona una tabla de clasificación que muestra las métricas de rendimiento de cada modelo, lo que facilita la identificación del modelo más prometedor para un problema en particular.</li>
# <br>
# <li><b>Optimización de hiperparámetros</b>: Los hiperparámetros son configuraciones que afectan el rendimiento y comportamiento de un modelo de aprendizaje automático. <code>PyCaret</code> realiza una búsqueda inteligente en el espacio de hiperparámetros para encontrar la combinación óptima que maximice el rendimiento del modelo.</li>
# <br>
# <li><b>Interpretación de modelos</b>: <code>PyCaret</code> ofrece herramientas para interpretar y visualizar los modelos de clasificación, lo que ayuda a comprender cómo toman decisiones y qué características son más importantes para el modelo.</li>
# <br>
# <li><b>Curvas ROC y Matrices de Confusión</b>: <code>PyCaret</code> proporciona curvas ROC (Receiver Operating Characteristic) y matrices de confusión para evaluar el rendimiento de los modelos de clasificación en diferentes umbrales de decisión.</li>
# <br>
# <li><b>Ensemble Learning</b>: <code>PyCaret</code> admite Ensemble Learning, que combina múltiples modelos para mejorar el rendimiento general y reducir el riesgo de sobreajuste (overfitting).</li>
# <br>
# <li><b>Predicción en nuevos datos</b>: Una vez que se ha construido y entrenado un modelo, PyCaret permite utilizarlo para hacer predicciones en nuevos datos sin la necesidad de escribir mucho código adicional.</li>
# </ol>
# <br>
# <p align="justify">
# El módulo de Clasificación de <code>PyCaret</code> está diseñado para ser amigable para principiantes, lo que permite a estudiantes y profesionales de Ciencia de Datos realizar tareas de clasificación complejas con mayor facilidad y rapidez. Al automatizar gran parte del proceso, <code>PyCaret</code> permite a los usuarios centrarse en la exploración de resultados, la interpretación de modelos y la toma de decisiones informadas en lugar de dedicar tiempo a tareas repetitivas.
# <br>
# <br>
# 💗 A disfrutar las Clasificaciones de <code>PyCaret</code>...
# </p>

# %% [markdown]
#  # **<font color="DeepPink">Instalando PyCaret...</font>**

# %% [markdown]
# <p align="justify"> 👀 Primero instalamos <code>PyCaret</code>:  </p>

# %%
# !pip install pycaret[full]

# %% [markdown]
#  # **<font color="DeepPink">Workflow</font>**

# %% [markdown]
# <h5 align="center"><b>
# <font color="DeepPink">
# <b>Setup ▶ Compare Models ▶ Analyze Model ▶ Prediction ▶ Save Model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  # **<font color="DeepPink">Obteniendo datos</font>**

# %%
# !pip install -U pycaret numpy --quiet

# %%
# Paso 1: Forzar reinstalación compatible de numpy y pycaret
# !pip uninstall -y numpy
# !pip install numpy==1.23.5 --quiet
# !pip install pycaret --quiet

# Paso 2: Instrucción al usuario
import os
import IPython

print("\n✅ Instalación completada. Ahora necesitas REINICIAR el entorno de ejecución.")
print("👉 Ve a 'Entorno de ejecución > Reiniciar entorno de ejecución', luego vuelve a ejecutar tu código.")
# Out:
# Found existing installation: numpy 1.23.5
# Uninstalling numpy-1.23.5:
#   Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# plotly-resampler 0.10.0 requires numpy>=1.24; python_version >= "3.11", but you have numpy 1.23.5 which is incompatible.
# interpret-core 0.6.10 requires numpy>=1.25, but you have numpy 1.23.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.5 which is incompatible.
# plotnine 0.14.5 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# chex 0.1.89 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# albumentations 2.0.6 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# ...

# %%
import numpy
print(numpy.__version__)
# Out:
# 1.26.4

# %%
from pycaret.datasets import get_data

# Cargar el dataset 'bank'
data = get_data('bank')

# Mostrar las primeras filas
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  unknown    5   may       261         1     -1         0  unknown      no
# 1  unknown    5   may       151         1     -1         0  unknown      no
# 2  unknown    5   may        76         1     -1         0  unknown      no
# 3  unknown    5   may        92         1     -1         0  unknown      no
# 4  unknown    5   may       198         1     -1         0  unknown      no
#    age           job  marital  education default  balance housing loan  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  deposit    45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# - Age =	Edad del cliente
# - Job=	Trabajo del cliente
# - Marital=  Estatus marital del cliente
# - Education	= Nivel de educacion del cliente
# - Default =	¿Tiene crédito en incumplimiento?
# - Housing = Si el cliente tiene un préstamo de vivienda
# - Loan	 = Sie el cliente tiene un prestamo personal
# - Balance	= Saldo individual del cliente
# - Contact	= Tipo de comunicación
# - Day = 	Último día de contacto de la semana
# - Month	 = Ultimo mes del año de contacto
# - Duration = 	Última duración de contacto, en segundos
# - Campaign= Número de contactos realizados durante esta campaña y para este cliente
# - Pdays= 	Número de días que pasaron después de que el cliente fue contactado por última vez de una campaña anterior
# - Previous= Número de contactos realizados antes de esta campaña y para este cliente
# - Poutcome	= Resultado de la campaña de marketing anterior
# - Deposit	 = ¿El cliente ha suscrito un depósito a plazo?

# %% [markdown]
#  **<font color="DeepPink"> En general, los conjuntos de datos que contienen datos de marketing se pueden utilizar para 2 objetivos comerciales diferentes:**
#
#
# Predicción de los resultados de la campaña de marketing para cada cliente y la aclaración de factores que afectan los resultados de la campaña. Esto ayuda a descubrir las formas en que las campañas de marketing sean más eficientes.
#
#
# **Encontrar segmentos de clientes, utilizando datos para los clientes, que se suscribieron al depósito a plazo. Esto ayuda a identificar el perfil de un cliente, que es más probable que adquiera el producto y desarrolle campañas de marketing más específicas.
# </font>**

# %% [markdown]
# >Este conjunto de datos contiene datos de la campaña de marketing bancario y podemos usarlos para optimizar las campañas de marketing para atraer a más clientes a la suscripción de depósito a término

# %% [markdown]
# # **<font color="DeepPink">Problema de Negocios, Metodologia en ciencia de datos:**
#
# 1.	Construir hipótesis a partir de variables comerciales que influyen en el caso de uso,
# 2.	Verificar las hipótesis utilizando análisis exploratorio de los datos (EDA),
# 3.	Derivar características basadas en intuiciones que se derivan del análisis exploratorio a través de la ingeniería de características de los datos;
# 4.	Construir modelos de clasificación,
# 5.	Analizar métricas de clasificación, y
# 6.	Formular planes de acción para la mejora del modelo, que contribuya a la toma de decisiones de la organización

# %% [markdown]
# # **<font color="DeepPink">01 - Setup</font>**
#
# <h5 align="center"><b>
# <font color="DeepPink">
# <b><mark>Setup</mark> ▶ Compare Models ▶ Analyze Model ▶ Prediction ▶ Save Model

# %% [markdown]
# <p align="justify">
# Esta función inicializa el entorno de entrenamiento y crea el pipeline de transformación. La función de configuración debe llamarse antes de ejecutar cualquier otra función en <code>PyCaret</code>.
# <br><br>
# 👀 <code>Setup()</code> tiene dos parámetros obligatorios, <code>data</code> y <code>target</code>. Todos los demás parámetros son opcionales.

# %%
from pycaret.classification import *

# %%
s = setup(data,
          target = 'deposit',
          normalize = True,
          session_id = 123)
# Out:
# <style type="text/css">
# #T_b53c5_row10_col1, #T_b53c5_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b53c5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b53c5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b53c5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b53c5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b53c5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b53c5_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b53c5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b53c5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b53c5_row1_col1" class="data row1 col1" >deposit</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# <p align="justify">
# La normalización es el proceso de ajustar los valores de una matriz para que se sitúen en un rango específico, típicamente $[0, 1]$. La normalización se puede definir como:
# <br><br>
# $$A_{\text{norm}} = \frac{A - \text{min}(A)}{\text{max}(A) - \text{min}(A)} $$
# <br><br>
# donde $ A_{\text{norm}} $ es la matriz normalizada.

# %% [markdown]
# # **<font color="DeepPink"> Detalles del Setup</font>**

# %% [markdown]
#  **<font color="DeepPink"> Session id</font>** Propiedad se usa para identificar de forma única un explorador con datos de sesión en el servidor

# %% [markdown]
#  **<font color="DeepPink"> Target</font>**-variable objetivo algoritmo de clasificacion binaria-"deposit"

# %% [markdown]
#  **<font color="DeepPink">Target type</font>**-tipo de variable objetivo -Binaria

# %% [markdown]
# **<font color="DeepPink">Target mapping</font>**=Mapeo de objetivo-si-no

# %% [markdown]
#  **<font color="DeepPink">Original data shape </font>** = formato de datos original(45211 filas, 17 columnas)

# %% [markdown]
#  **<font color="DeepPink">Transformed data shape  </font>** = formato de datos original transformado = (45211 filas, 19 columnas)

# %% [markdown]
#  **<font color="DeepPink">Transformed train data shape  </font>**formato de datos de entrenamiento transformados (31647 filas, 49 columnas)

# %% [markdown]
# **<font color="DeepPink">Transformed test data shape  </font>**formato de datos de testeo transformados (13547 filas, 49 columnas)

# %% [markdown]
#  **<font color="DeepPink">Numeric features  </font>**= variables numericas

# %% [markdown]
#  **<font color="DeepPink">Categorical features  </font>**= variables categoricas

# %% [markdown]
# **<font color="DeepPink">Preprocess </font>**= Preprocesamiento True

# %% [markdown]
#  **<font color="DeepPink">Imputation type  </font>**= Tipo de imputacion de las variables numericas simple

# %% [markdown]
#  **<font color="DeepPink">Numeric imputation  </font>**= Imputacion numerica

# %% [markdown]
#  **<font color="DeepPink">Categorical imputation  </font>**= Imputacion Categorica

# %% [markdown]
# **<font color="DeepPink">Fold Generator  </font>**= metodo de division de separacion del conjunto de entrenamiento y testeo

# %% [markdown]
#  **<font color="DeepPink">Fold Number  </font>**= numero de pliegues en validacion cruzada,La validación cruzada es una técnica para evaluar modelos de ML mediante el entrenamiento de varios modelos de ML en subconjuntos de los datos de entrada disponibles y evaluarlos con el subconjunto complementario de los datos.Numero de pliegues que va a generar entrenamiento y testeo

# %% [markdown]
#  **<font color="DeepPink">CPU jobs= -1  </font>**=  cantidad de procesadores en disponibles todos menos 1

# %% [markdown]
#  **<font color="DeepPink">Use-GPU-False  </font>**=  No usa procesador La unidad de procesamiento de gráficos (GPU) es un circuito electrónico que puede realizar cálculos matemáticos a alta velocidad. Algunas tareas de computación, como la renderización de gráficos, el machine learning (ML) y la edición de videos, requieren la aplicación de operaciones matemáticas similares en un conjunto de datos grande. El diseño de una GPU le permite realizar la misma operación en varios valores en paralelo. Esto vuelve más eficiente el procesamiento de muchas tareas que requieren mucha capacidad de cómputo.

# %% [markdown]
#  **<font color="DeepPink">Log Experiment= False  </font>**= Un (lista de) PyCaret BaseLoggero str (uno de mlflow, wandb, comet_mlo dagshub) correspondiente a un registrador para determinar qué registradores de experimentos usar. Al configurarlo, Truese usará solo MLFlow.

# %%
get_config('dataset')
# Out:
#        age          job  marital  education default  balance housing loan  \
# 44828   34   management  married   tertiary      no     3301     yes   no
# 11344   47     services  married    primary      no      504      no  yes
# 28435   26  blue-collar   single    primary      no      155     yes   no
# 39971   23   technician   single  secondary      no     4545      no   no
# 5747    47   management   single   tertiary      no      191     yes   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 39833   34   management  married   tertiary      no      690     yes   no
# 32030   25      student   single  secondary      no     1765     yes   no
# 4644    33     services   single  secondary      no        0     yes   no
# 4091    50     services  married  secondary      no     1463     yes   no
# 44440   38       admin.   single  secondary      no      115      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
get_config('dataset').info() # dataset original
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45211 entries, 44828 to 44440
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int8
#  1   job        45211 non-null  category
#  2   marital    45211 non-null  category
#  3   education  45211 non-null  category
#  4   default    45211 non-null  category
#  5   balance    45211 non-null  int32
#  6   housing    45211 non-null  category
#  7   loan       45211 non-null  category
#  8   contact    45211 non-null  category
#  9   day        45211 non-null  int8
#  10  month      45211 non-null  category
#  11  duration   45211 non-null  int32
#  12  campaign   45211 non-null  int8
#  13  pdays      45211 non-null  int32
#  14  previous   45211 non-null  int32
#  15  poutcome   45211 non-null  category
#  16  deposit    45211 non-null  category
# dtypes: category(10), int32(4), int8(3)
# memory usage: 2.6 MB

# %%
get_config('dataset_transformed').info() # dataset original transformado
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45211 entries, 44828 to 44440
# Data columns (total 49 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  45211 non-null  float64
#  1   job_management       45211 non-null  float64
#  2   job_services         45211 non-null  float64
#  3   job_blue-collar      45211 non-null  float64
#  4   job_technician       45211 non-null  float64
#  5   job_entrepreneur     45211 non-null  float64
#  6   job_student          45211 non-null  float64
#  7   job_retired          45211 non-null  float64
#  8   job_admin.           45211 non-null  float64
#  9   job_housemaid        45211 non-null  float64
#  10  job_self-employed    45211 non-null  float64
#  11  job_unemployed       45211 non-null  float64
#  12  job_unknown          45211 non-null  float64
#  13  marital_married      45211 non-null  float64
#  14  marital_single       45211 non-null  float64
# ...

# %% [markdown]
# Un pipeline es un conjunto de procesos o sistemas utilizados para recopilar datos en una secuencia de pasos o etapas interconectadas, donde la finalización de una etapa se convierte en la entrada de la siguiente

# %% [markdown]
# Por defecto, el valor medio se usa para la imputación de características numéricas y el valor más frecuente se usa para características categóricas.
#
# Se puede cambiar el método de imputación mediante el parámetro numeric_imputation y categorical_imputation, tal como se lo detallo previamente.
#
# Para los modelos de clasificación, la configuración también realiza la codificación de destino en forma automática. Esto es de gran utilidad y ayuda.

# %%
get_config('pipeline')
# Out:
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(exclude=None, include=None,
#                                                transformer=LabelEncoder())),
#                 ('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['age', 'balance', 'day',
#                                              'duration', 'campaign', 'pdays',
#                                              'previous'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_valu...
#                                     transformer=OneHotEncoder(cols=['job',
#                                                                     'marital',
# ...

# %% [markdown]
# - label enconder = variable categorica sexo.fem mas-en la misma columna 0 aparezca primero alfabeticamente en la misma columna

# %% [markdown]
# - numeric imputer -imputacion de valores faltantes de la media

# %% [markdown]
# - categorical imputation- simple las mas frecuente

# %% [markdown]
# - ordinal enconding categoricas - categoriza ordinal

# %% [markdown]
# - variable categorica pocas categorias.-ordinal una sola columna

# %% [markdown]
# - categoricas one hot encoding-mas categorias

# %% [markdown]
# - pocas ordinal muchas one hot encoding

# %% [markdown]
# - normalize = standard scaler transformarlas en la normal standard media 0 desvio estandard 1-

# %% [markdown]
# # **<font color="DeepPink">02 - Compare Models</font>**
#
# <h5 align="center"><b>
# <font color="DeepPink">
# <b><mark>Setup</mark> ▶ <mark>Compare Models</mark> ▶ Analyze Model ▶ Prediction ▶ Save Model

# %% [markdown]
# <p align="justify">
# Esta función entrena y evalúa el rendimiento de todos los estimadores disponibles en la biblioteca de modelos mediante validación cruzada.
# <br><br>
# El resultado de esta función es una cuadrícula de puntuación con medias validadas de forma cruzada. Se puede acceder a las métricas evaluadas durante validacion cruzada mediante la función <code>get_metrics</code>. Las métricas personalizadas se pueden agregar o eliminar usando la función <code>add_metric</code> y <code>remove_metric</code>

# %%
##remove_metric("auc") # remuevo metricas antes de comparar el modelo
##remove_metric("kappa")
##remove_metric("mcc")

# %%
best = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             19:18:53
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
# <style type="text/css">
# #T_d4f9e th {
#   text-align: left;
# }
# ...

# %% [markdown]
# - Los algoritmos que se ejecuten en los diferentes modelos serán evaluados para poder tener un ranking del mejor desempeño de los mismos, esa evaluación se llevará a cabo con la matriz de confusión y la matriz de rendimiento-metricas de clasificacion

# %%
best

# %% [markdown]
# Hiperparametros del algoritmo, no todos se usan..en la optimizacion

# %% [markdown]
# - boosting_type (str, optional (default='gbdt')) – ‘gbdt’, traditional Gradient Boosting Decision Tree. ‘dart’, Dropouts meet Multiple Additive Regression Trees. ‘rf’, Random Forest.___ Gradiente-por default Gradiente Boosting Decision Tree

# %% [markdown]
# - class_weight (dict, 'balanced' or None, optional (default=None)) – Weights associated with classes in the form {class_label: weight}. ##Use this parameter only for multi-class classification task; for binary classification task you may use is_unbalance or scale_pos_weight parameters.-##Pësos de clase solo para clasificacion multiclase

# %% [markdown]
# - colsample_bytree (float, optional (default=1.)) – Subsample(submuestra) ratio of columns when constructing each tree.Submuestra de columna del arbol por default = 1

# %% [markdown]
#  - importance_type (str, optional (default='split')) – The type of feature importance to be filled into feature_importances_. If ‘split’, result contains numbers of times the feature is used in a model. If ‘gain’, result contains total gains of splits which use the feature.- "Divide", el resultado contiene un número de veces que la característica se usa en un modelo-por default divide(split)

# %% [markdown]
# - learning_rate (float, optional (default=0.1)) – Boosting learning rate. You can use callbacks parameter of fit method to shrink/adapt learning rate in training using reset_parameter callback. Note, that this will ignore the learning_rate argument in training.- TASA DE APRENDIZAJE ES UNO DE LOS HYPERPARAMETROS MAS IMPORTANTES EN LOS MODELOS

# %% [markdown]
# - max_depth (int, optional (default=-1)) – Maximum tree depth for base learners, <=0 means no limit.-Profundidad maxima del arbol.-1

# %% [markdown]
# - min_child_weight (float, optional (default=1e-3)) – Minimum sum of instance weight (Hessian) needed in a child (leaf).-Suma minima de peso de instancia-0.001

# %% [markdown]
# - min_split_gain (float, optional (default=0.)) – Minimum loss reduction required to make a further partition on a leaf node of the tree.-Reducción mínima de pérdida requerida para hacer una partición adicional en un nodo de hoja del árbol.0.0

# %% [markdown]
# - n_estimators (int, optional (default=100)) – Number of boosted trees to fit.- número de árboles impulsados-100

# %% [markdown]
# - n_jobs (int or None, optional (default=None)) Number of parallel threads to use for training (can be changed at prediction time by passing it as an extra keyword argument).For better performance, it is recommended to set this to the number of physical cores in the CPU.
#
# - Número de hilos paralelos para usar para el entrenamiento (se puede cambiar en el tiempo de predicción pasando como un argumento de palabras clave adicional).
# Para un mejor rendimiento, se recomienda establecer esto en el número de núcleos físicos en la CPU.

# %% [markdown]
#  - num_leaves (int, optional (default=31)) – Maximum tree leaves for base learners.-hojas máximas del árbol.-31

# %% [markdown]
# - objective (str, callable or None, optional (default=None)) – Specify the learning task and the corresponding learning objective or a custom objective function to be used (see note below).-Especifique la tarea de aprendizaje y el objetivo de aprendizaje correspondiente o una función de objetivo personalizado que se utilizará -None

# %% [markdown]
# - random_state (int, RandomState object or None, optional (default=None)) – Random number seed. If int.Semilla=123

# %% [markdown]
# - reg_alpha (float, optional (default=0.)) – L1 regularization term on weights.Metodo de regularizacion L1

# %% [markdown]
# - reg_lambda (float, optional (default=0.)) – L2 regularization term on weights.-Metodo de regularizacion L2

# %% [markdown]
# - subsample (float, optional (default=1.)) – Subsample ratio of the training instance.-Relación submuestra de la instancia de entrenamiento.

# %% [markdown]
# - subsample_for_bin (int, optional (default=200000)) – Number of samples for constructing bins.-Número de muestras para construir contenedores.

# %% [markdown]
# - subsample_freq (int, optional (default=0)) – Frequency of subsample, <=0 means no enable.-Frecuencia de submuestra

# %% [markdown]
# https://lightgbm.readthedocs.io/en/stable/ ### documentacion del algoritmo

# %% [markdown]
#  **<font color="DeepPink">  Usaramos xgboost, que es una de las bibliotecas de aprendizaje automático más comunes para el modelado. El modelo resultante también me ayudará a comprender, que las características tienen la mayor importancia para la predicción de los resultados de la campaña.</font>**

# %% [markdown]
#  ## **<font color="DeepPink">Metricas</font>**

# %% [markdown]
#  ### **<font color="DeepPink">Accuracy</font>**

# %% [markdown]
# <p align="justify">
# <b>Accuracy</b> es una métrica comúnmente utilizada para evaluar el rendimiento de un modelo de clasificación. Esta métrica mide la proporción de instancias clasificadas correctamente por el modelo sobre el total de instancias en el conjunto de datos de prueba.
# <br><br>
# Accuracy se calcula dividiendo el número de predicciones correctas (tanto verdaderos positivos como verdaderos negativos) entre el número total de instancias en el conjunto de prueba. La fórmula es la siguiente:
# <br><br>
# Accuracy = $\frac{(VP + VN)}{Total}$
# <br><br>
# Los términos de la fórmula:<br><br>
# <ul align="justify">
# <li><b>Verdaderos positivos (VP)</b>: Son los casos positivos que el modelo clasifica correctamente como positivos.</li><br>
# <li><b>Verdaderos negativos (VN)</b>: Son los casos negativos que el modelo clasifica correctamente como negativos.</li><br>
# </ul>
# <p align="justify">
# En otras palabras, accuracy nos dice cuántas de las predicciones del modelo son correctas en comparación con todas las predicciones realizadas.
# <br><br>
# <mark>Accuracy es una métrica útil cuando las clases están bien equilibradas</mark> en el conjunto de datos, es decir,<mark>cuando el número de instancias de una clase es aproximadamente igual al número de instancias de la otra clase</mark>. Sin embargo, accuracy puede ser engañosa si las clases están desequilibradas, ya que un modelo puede alcanzar alta accuracy al simplemente predecir siempre la clase mayoritaria en un conjunto de datos desequilibrado, pero sin ser capaz de generalizar bien a otras clases.
# <br><br>
# En casos de conjuntos de datos desequilibrados, es importante considerar otras métricas...

# %% [markdown]
# ***Mide el porcentaje de los casos que el modelo ha acertado, se selecciona el de mayor accuracy***

# %% [markdown]
#  ### **<font color="DeepPink">Recall</font>**

# %% [markdown]
# <p align="justify">
# <b>Recall</b> (también conocido como sensibilidad o tasa de verdaderos positivos) es una métrica utilizada para evaluar el rendimiento de un modelo de clasificación, especialmente cuando el objetivo es identificar correctamente casos positivos en un conjunto de datos.
# <br><br>
# Recall se define como la proporción de casos positivos que el modelo ha identificado correctamente sobre el total de casos positivos en el conjunto de datos. En otras palabras, es la capacidad del modelo para "recordar" o "capturar" correctamente los casos de la clase positiva.
# <br><br>
# La fórmula para calcular el Recall es la siguiente:
# <br><br>
# Recall = $\frac{VP}{VP + FN}$
# <br><br>
# Los términos de la fórmula:<br><br>
# <ul align="justify">
# <li><b>Verdaderos positivos (VP)</b>: Son los casos positivos que el modelo clasifica correctamente como positivos.</li><br>
# <li><b>Falsos negativos (FN)</b>: Son los casos positivos que el modelo clasifica incorrectamente como negativos</li><br>
# </ul>
# <p align="justify">
# Recall mide la capacidad del modelo para encontrar y capturar todos los casos positivos en el conjunto de datos. Es especialmente útil en problemas donde la detección de casos positivos es crucial, como en aplicaciones médicas donde la identificación de enfermedades o en problemas de detección de fraudes.
# <br><br>
# Es importante tener en cuenta que Recall y Accuracy están relacionados, pero también pueden ser contradictorios. A medida que el modelo se vuelve más sensible y mejora su Recall al capturar más casos positivos, puede aumentar la cantidad de falsos positivos (casos negativos que se clasifican incorrectamente como positivos), lo que podría disminuir la precisión.
# <br><br>
# Por lo tanto, la elección de la métrica adecuada depende del contexto y los objetivos del problema. Si se prioriza la identificación correcta de los casos positivos, Recall es una métrica clave a considerar.

# %% [markdown]
#  ***Se selecciona el modelo con exhaustividad o recall mayor.***

# %% [markdown]
#  ### **<font color="DeepPink">Precision</font>**

# %% [markdown]
# <p align="justify">
# <b>Precision</b> (también conocido como valor predictivo positivo) es otra métrica importante utilizada para evaluar el rendimiento de un modelo de clasificación. La Precision se enfoca en la proporción de instancias clasificadas como positivas por el modelo que realmente son verdaderos positivos, es decir, la precisión en las predicciones positivas del modelo.
# <br><br>
# La fórmula para calcular la Precision es la siguiente:
# <br><br>
# Precision = $\frac{VP}{VP + FP}$
# <br><br>
# Los términos de la fórmula significan lo siguiente:<br><br>
# <ul align="justify">
# <li><b>Verdaderos positivos (VP)</b>: Son los casos positivos que el modelo clasifica correctamente como positivos.</li><br>
# <li><b>Falsos positivos (FP)</b>: Son los casos negativos que el modelo clasifica incorrectamente como positivos</li><br>
# </ul>
# <p align="justify">
# En otras palabras, la Precision mide la proporción de las instancias clasificadas como positivas que realmente son casos positivos entre todas las instancias clasificadas como positivas.
# <br><br>
# La Precision es particularmente relevante en situaciones donde el costo de los falsos positivos es alto, es decir, cuando clasificar incorrectamente una instancia como positiva tiene consecuencias graves o costosas. Un alto valor de Precision indica que el modelo es preciso en sus predicciones positivas y minimiza los errores de clasificación de casos negativos como positivos.
# <br><br>
# Es importante tener en cuenta que la Precision y el Recall (sensibilidad) están relacionados y suelen ser compensatorios entre sí. A medida que se mejora la Precision al reducir los falsos positivos, es probable que disminuya el Recall, lo que implica que se pueden perder algunos verdaderos positivos. Por lo tanto, encontrar el equilibrio adecuado entre la Precision y el Recall depende de las necesidades y objetivos específicos del problema.
# <br><br>
# En resumen, la Precision es una métrica crucial en la evaluación del rendimiento de un modelo de clasificación, especialmente en escenarios donde la precisión en las predicciones positivas es de gran importancia.
# <br><br>
# 👀 Sin embargo, para obtener una visión completa del rendimiento del modelo, es necesario considerar otras métricas, como por ejemplo: el F1-score, que combina la Precision y el Recall en una única medida.

# %% [markdown]
#  ***Se selecciona el modelo con mayor precisión***

# %% [markdown]
#  ### **<font color="DeepPink">F1</font>**

# %% [markdown]
# <p align="justify">
# <b>F1</b> (también conocido como F-score o medida F) es una métrica utilizada en la evaluación de modelos de clasificación binaria que combina Precision y el Recall en una única medida.
# <br><br>
# Esta métrica es útil cuando se desea encontrar un equilibrio entre la precisión de las predicciones positivas y la capacidad de identificar correctamente los casos positivos en el conjunto de datos.
# <br><br>
# El F1-score se calcula como la media armónica entre la Precision y el Recall y se define mediante la siguiente fórmula:
# <br><br>
# F1 = $2 \times \frac{Precision \times Recall}{Precision + Recall}$
# <br><br>
# La media armónica se utiliza para combinar Precision y Recall en el F1-score porque penaliza más fuertemente los valores bajos. Esto significa que si una de las dos métricas tiene un valor bajo, el F1-score también será bajo, lo que destaca situaciones donde el modelo tiene un desequilibrio significativo entre Precision y Recall.
# <br><br>
# <mark>F1-score proporciona una medida más equilibrada del rendimiento del modelo en comparación con la precisión o el recall por separado, especialmente cuando las clases están desequilibradas</mark> en el conjunto de datos. En problemas donde la precisión de las predicciones positivas y la capacidad de detectar correctamente los casos positivos son igualmente importantes, el F1-score es una métrica valiosa.
# <br><br>
# Es esencial considerar el contexto y los objetivos del problema al elegir la métrica de evaluación más adecuada.
# <br><br>
# ✅ Si se da prioridad a la identificación correcta de los casos positivos, el Recall es relevante.<br>
# ✅ Si se necesita alta precisión en las predicciones positivas y la identificación de casos positivos no es tan crucial, la Precision puede ser más relevante.<br>
# ✅ Sin embargo, si se busca un equilibrio entre ambas, el F1-score es la métrica.

# %% [markdown]
# El valor F1-score se utiliza para combinar medidas de precisión y exhaustividad en un sólo valor, como alternativa a la métrica de exactitud

# %% [markdown]
# El valor F1-score asume que importa de igual forma la precisión y la exhaustividad. Esto no tiene necesariamente que ser así en todos los problemas que se formulen

# %% [markdown]
#  **<font color="DeepPink">El Coeficiente kappa de Cohen es una medida estadística que ajusta el efecto del azar en la proporción de la concordancia observada</font>**

# %% [markdown]
#  <font color="DeepPink">El coeficiente de correlación de Matthews (MCC) oscila entre -1 y 1, donde 1 significa que el modelo predijo correctamente todas las muestras. MCC se calcula como: </font>
#
#  $$((VP x VN) - (FP x FN)) / [(VP + FP) x (FN + VN) x (FP + VN) x (VP + FN)]^(1/2)$$

# %% [markdown]
#  ## **<font color="DeepPink">Modelo</font>**

# %% [markdown]
# 👀 Podemos ver los hiperparámetros del mejor modelo...

# %% [markdown]
# 👀 Podemos pasar los valores del mejor modelo a un <code>DataFrame</code> con la función <code>pull()</code>

# %%
best_DataFrame = pull()
best_DataFrame

# %% [markdown]
# 👀 Los modelos disponibles son:

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
len(models())

# %% [markdown]
# ###Hay que tener en cuenta que elegir un algoritmo de clasificación apropiado para un problema de negocios requiere mucha práctica y también mucha experiencia porque cada algoritmo de clasificación tiene características propias, y por lo tanto ningún clasificador funciona mejor en todos los escenarios de negocios posibles que pueden llegar a plantearse o puedan llegar a presentarse

# %% [markdown]
# # **<font color="DeepPink">03 - Analyze Model</font>**
#
# <h5 align="center"><b>
# <font color="DeepPink">
# <b><mark>Setup</mark> ▶ <mark>Compare Models</mark> ▶ <mark>Analyze Model</mark> ▶ Prediction ▶ Save Model

# %% [markdown]
# Puede usar la función <code>plot_model</code> para analizar el rendimiento de un modelo entrenado en el conjunto de prueba. Tambien se puede requerir volver a entrenar el modelo en determinados casos.

# %% [markdown]
#  ## **<font color="DeepPink">Matriz de confusión</font>**

# %% [markdown]
# <p align="justify">
# La matriz de confusión es una herramienta comúnmente utilizada para evaluar el rendimiento de un modelo de clasificación, especialmente cuando se trata de problemas de dos clases, como la clasificación binaria, donde solo hay dos clases posibles: la clase 0 y la clase 1.
# <br>
# <br>
# En un modelo de clasificación binaria, los resultados de las predicciones se pueden resumir en cuatro términos:
#
# <ol align="justify">
# <li><b>Verdaderos positivos (TP)</b>: Representa el número de muestras que pertenecen a la clase 1 (positiva) y fueron clasificadas correctamente como clase 1.</li><br>
# <li><b>Verdaderos negativos (TN)</b>: Representa el número de muestras que pertenecen a la clase 0 (negativa) y fueron clasificadas correctamente como clase 0.</li><br>
# <li><b>Falsos positivos (FP)</b>: Representa el número de muestras que pertenecen a la clase 0 (negativa) pero fueron incorrectamente clasificadas como clase 1.</li><br>
# <li><b>Falsos negativos (FN)</b>: Representa el número de muestras que pertenecen a la clase 1 (positiva) pero fueron incorrectamente clasificadas como clase 0.</li>

# %%
plot_model(best, plot = 'confusion_matrix', scale=0.7)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
(11523+827)+(760+454) # total observaciones testeo
# Out:
# 13564

# %%
round((11523+827)/13564, 5) #accuracy
# Out:
# 0.9105

# %%
round((11523)/(11523+454), 4) #recall
# Out:
# 0.9621

# %%
round((11523)/(11523+760), 4) #precision
# Out:
# 0.9381

# %% [markdown]
#  ## **<font color="DeepPink">Curva ROC</font>**

# %% [markdown]
# <p align="justify">
# La Curva ROC (Receiver Operating Characteristic) es una herramienta gráfica que se utiliza para evaluar el rendimiento de un modelo de clasificación binaria.
# <br><br>
# Es una representación visual de la sensibilidad (tasa de verdaderos positivos) frente a la tasa de falsos positivos $(1 - especificidad)$ para diferentes umbrales de decisión.
# <br><br>
# Aquí está la explicación paso a paso de cómo se construye la Curva ROC:
# <br><br>
# <ol align="justify">
# <li><b>Definición de términos</b>:</li>
# <ul align="justify">
# <li><b>Verdaderos positivos (VP)</b>: Son los casos positivos que el modelo clasifica correctamente como positivos.</li><br>
# <li><b>Falsos positivos (FP)</b>: Son los casos negativos que el modelo clasifica incorrectamente como positivos.</li><br>
# <li><b>Verdaderos negativos (VN)</b>: Son los casos negativos que el modelo clasifica correctamente como negativos.</li><br>
# <li><b>Falsos negativos (FN)</b>: Son los casos positivos que el modelo clasifica incorrectamente como negativos</li><br>
# </ul>
# <li><b>Variación del umbral de decisión</b>:
#    Un modelo de clasificación binaria asigna probabilidades o puntajes a cada instancia para determinar si pertenece a la clase positiva o negativa. Al cambiar el umbral de decisión, es posible ajustar el equilibrio entre la sensibilidad y la especificidad del modelo.</li><br>
# <li><b>Cálculo de la sensibilidad y especificidad</b>:
#    Para cada umbral de decisión, se calculan la sensibilidad y la especificidad del modelo. La sensibilidad se define como la tasa de verdaderos positivos $\frac {VP} {VP + FN}$, mientras que la especificidad se define como la tasa de verdaderos negativos $\frac {VN}{VN + FP}$.</li><br>
# <li><b>Construcción de la Curva ROC</b>:
#    La Curva ROC se crea trazando la sensibilidad en el eje $Y$ (eje vertical) y el complemento de la especificidad $(1 - especificidad)$ en el eje $X$ (eje horizontal). A medida que el umbral de decisión varía, se obtienen diferentes puntos en la curva.</li><br>
# <li><b>Interpretación de la Curva ROC</b>:
#    La Curva ROC muestra cómo varía el equilibrio entre la sensibilidad y la especificidad a diferentes niveles de umbral de decisión. Un modelo con un rendimiento excelente tendría una curva ROC que se acerca al vértice superior izquierdo del gráfico, lo que indica una alta sensibilidad y una baja tasa de falsos positivos. Un modelo sin capacidad de discriminación tendría una curva ROC que se asemeja a la línea diagonal (tasa de verdaderos positivos igual a tasa de falsos positivos).</li></ol>
# <br>
# <p align="justify">
# Además de la Curva ROC, se utiliza el área bajo la curva (AUC, Area Under the Curve) como una métrica resumen del rendimiento del modelo. El AUC mide la capacidad de discriminación del modelo en general, y un valor de AUC cercano a $1$ indica un mejor rendimiento del modelo. En cambio, un valor cercano a $0.94$ indica que el modelo  supera el rendimiento aleatorio y, por lo tanto, es  útil.

# %%
plot_model(best, plot = 'auc', scale=0.9)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  ## **<font color="DeepPink">Importancia de Variables</font>**

# %% [markdown]
# <p align="justify">
# La "Feature Importance" o importancia de variables o caracteristicas, es un concepto utilizado en el contexto del aprendizaje automático (machine learning) y, en particular, en modelos de clasificación o regresión. Se refiere a una técnica que permite determinar la contribución relativa de cada característica o variable utilizada en el modelo para realizar las predicciones.
# <br><br>
# Cuando se entrena un modelo de aprendizaje automático, como un algoritmo de clasificación (por ejemplo, Random Forest, Gradient Boosting, etc.) o un algoritmo de regresión (por ejemplo, Regresión Lineal, Lasso, etc.), el modelo utiliza un conjunto de características o variables (también conocidas como atributos o columnas) para hacer predicciones.
# <br><br>
# La importancia de características nos ayuda a responder preguntas como:
# <br><br>
# <ul aling="justify">
# <li>¿Cuáles son las características más influyentes para el modelo en sus predicciones?</li><br>
# <li>¿Cuáles características pueden ser descartadas sin afectar significativamente el rendimiento del modelo?</li><br>
# <li>¿Cuáles características tienen una correlación más fuerte con la variable objetivo (o la variable a predecir)?</li></ul><br>
# <p align="justify">
# Hay varias formas de calcular la importancia de características, y algunos algoritmos ya proporcionan esta información directamente después de ser entrenados.
# <br><br>
# Algunas de las técnicas comunes para calcular la importancia de características son:
# <br>
# <ol align="justify">
# <li><b>Importancia basada en árboles (Tree-based Importance)</b>:
#    En algoritmos de árboles, como Random Forest o Gradient Boosting, la importancia de características se puede calcular al observar cómo cada característica afecta la precisión de la predicción en el árbol. Las características que se utilizan para tomar decisiones en los niveles superiores del árbol o <mark>que reducen la impureza</mark> (como la entropía o la ganancia de información) en mayor medida, generalmente se consideran más importantes.</li><br>
# <li><b>Coeficientes en regresión lineal</b>:
#    En modelos de regresión lineal o regresión lineal regularizada (por ejemplo, Lasso, Ridge), los coeficientes asociados con cada característica indican su contribución a la predicción. Los coeficientes más grandes, en valor absoluto, indican que esa característica tiene una mayor influencia en las predicciones.</li><br>
# <li><b>Permutación de características (Permutation Feature Importance)</b>:
#    En este enfoque, se mide cómo cambia el rendimiento del modelo cuando se permutan aleatoriamente los valores de una característica específica mientras se evalúa en un conjunto de prueba. <mark>Si una característica es importante, su permutación causará una disminución significativa en el rendimiento del modelo</mark>.</li></ol><br>
# <p align="justify">
# La importancia de características es una herramienta útil para comprender y analizar el comportamiento de un modelo de aprendizaje automático, así como para identificar qué características tienen un mayor impacto en las predicciones.
# <br><br>
# Sin embargo, debe utilizarse con precaución, ya que la interpretación de la importancia puede variar según el contexto y el problema específico que se esté abordando.

# %%
plot_model(best, plot = 'feature', scale=0.78)

# %% [markdown]
# - duration: Última duración de contacto, en segundos
# - day : Último día de contacto de la semana
# - Balance: Saldo individual del cliente
# - Age : Edad

# %% [markdown]
#  ## **<font color="DeepPink">4-Evaluación</font>**

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# # **<font color="DeepPink">05 - Prediction</font>**
#
# <h5 align="center"><b>
# <font color="DeepPink">
# <b><mark>Setup</mark> ▶ <mark>Compare Models</mark> ▶ <mark>Analyze Model</mark> ▶ <mark>Prediction</mark> ▶ Save Model

# %% [markdown]
# <p align="justify">
# La función <code>predict_model</code> devuelve la etiqueta de predicción y la puntuación de predicción (probabilidad de la clase predicha) como columnas nuevas en el DataFrame.

# %%
holdout_pred = predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ee4bb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee4bb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ee4bb_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ee4bb_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ee4bb_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ee4bb_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ee4bb_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ee4bb_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ee4bb_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee4bb_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
holdout_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13564 entries, 5997 to 44440
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               13564 non-null  int8
#  1   job               13564 non-null  category
#  2   marital           13564 non-null  category
#  3   education         13564 non-null  category
#  4   default           13564 non-null  category
#  5   balance           13564 non-null  int32
#  6   housing           13564 non-null  category
#  7   loan              13564 non-null  category
#  8   contact           13564 non-null  category
#  9   day               13564 non-null  int8
#  10  month             13564 non-null  category
#  11  duration          13564 non-null  int32
#  12  campaign          13564 non-null  int8
#  13  pdays             13564 non-null  int32
#  14  previous          13564 non-null  int32
#  15  poutcome          13564 non-null  category
# ...

# %%
holdout_pred.head() # dataset de testeo
# Out:
#        age           job   marital  education default  balance housing loan  \
# 5997    26   blue-collar    single  secondary      no      339     yes   no
# 39268   34   blue-collar   married  secondary      no      463     yes   no
# 9555    59       retired   married  secondary      no      444     yes   no
# 9044    47  entrepreneur   married  secondary      no        0      no   no
# 42981   34    management  divorced   tertiary      no     2885      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 5997    unknown   26   may       165         5     -1         0  unknown
# 39268  cellular   18   may        11        11    360         4  failure
# 9555    unknown    6   jun       137         1     -1         0  unknown
# 9044    unknown    5   jun      1446         1     -1         0  unknown
# 42981  cellular   10   feb       314         2    156         4    other
#
#       deposit prediction_label  prediction_score
# ...

# %% [markdown]
# <p align="justify">
# La misma función se puede utilizar para predecir las etiquetas en conjuntos de datos no vistos.
# <br><br>
# 👀 Podemos crear una copia de los datos originales. Entonces podemos usar el nuevo DataFrame sin etiquetas para puntuar.

# %%
new_data = data.copy()
new_data.drop('deposit', axis=1, inplace=True)
new_data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome
# 0  unknown    5   may       261         1     -1         0  unknown
# 1  unknown    5   may       151         1     -1         0  unknown
# 2  unknown    5   may        76         1     -1         0  unknown
# 3  unknown    5   may        92         1     -1         0  unknown
# 4  unknown    5   may       198         1     -1         0  unknown

# %%
new_data.info() # el dataset completo de testeo
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 5.5+ MB

# %%
predictions = predict_model(best, data = new_data)
predictions.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  unknown    5   may       261         1     -1         0  unknown
# 1  unknown    5   may       151         1     -1         0  unknown
# 2  unknown    5   may        76         1     -1         0  unknown
# 3  unknown    5   may        92         1     -1         0  unknown
# 4  unknown    5   may       198         1     -1         0  unknown
#
#   prediction_label  prediction_score
# 0               no            0.9961
# 1               no            0.9981
# ...

# %% [markdown]
# # **<font color="DeepPink">-Prediccion nuevos datos variable objetivo</font>**

# %%
predictions.prediction_label.value_counts() #  prediccion de que depositaran el conjunto de clientes del modelo
# Out:
# prediction_label
# no     40932
# yes     4279
# Name: count, dtype: int64

# %%
porcentaje_prediccion = round(predictions.prediction_label.value_counts()[0]/len(predictions), 4)
porcentaje_prediccion
# Out:
# 0.9054

# %% [markdown]
# # **<font color="DeepPink">Variable Objetivo</font>**

# %%
data.deposit.value_counts() # prediccion de que depositaran el conjunto de clientes del Data Frame
# Out:
# deposit
# no     39922
# yes     5289
# Name: count, dtype: int64

# %%
porcentaje_original = round(data.deposit.value_counts()[0]/len(data), 4)
porcentaje_original
# Out:
# 0.883

# %% [markdown]
# # **<font color="DeepPink">06 - Conclusiones????</font>**

# %% [markdown]
# # **<font color="DeepPink">Analisis del Modelo y Conclusiones sobre el dataset original</font>**

# %%
plot_model(best, plot='feature', scale=0.8) ## caracteristicas mas importantes del modelo

# %%
duration = data[["duration","deposit"]].head(10) ## relacion entre Duration = Última duración de contacto, en segundos, y el deposito

# %%
duration
# Out:
#    duration deposit
# 0       261      no
# 1       151      no
# 2        76      no
# 3        92      no
# 4       198      no
# 5       139      no
# 6       217      no
# 7       380      no
# 8        50      no
# 9        55      no

# %%
duration_valores = data[["duration","deposit"]].value_counts()## relacion entre Duration = Última duración de contacto, en segundos, y el deposito
duration_valores
# Out:
# duration  deposit
# 124       no         182
# 90        no         181
# 114       no         171
# 89        no         170
# 88        no         169
#                     ...
# 1161      yes          1
# 1162      yes          1
# 748       yes          1
# 743       no           1
# 4918      no           1
# Name: count, Length: 2627, dtype: int64

# %%
day_valores = data[["day","deposit"]].value_counts()## relacion entre day = Day = Último día de contacto de la semana y el deposito
day_valores
# Out:
# day  deposit
# 20   no         2560
# 18   no         2080
# 21   no         1825
# 17   no         1763
# 6    no         1751
#                 ...
# 10   yes         121
# 26   yes         116
# 1    yes          90
# 24   yes          62
# 31   yes          46
# Name: count, Length: 62, dtype: int64

# %%
balance_valores = data[["balance","deposit"]].value_counts()## relacion entre balance  = Saldo individual del cliente
balance_valores
# Out:
# balance  deposit
# 0        no         3222
#          yes         292
# 1        no          178
# 2        no          140
# 4        no          128
#                     ...
# 3282     no            1
# 3286     yes           1
# 3288     yes           1
# 3291     no            1
# 102127   no            1
# Name: count, Length: 9258, dtype: int64

# %%
age_valores = data[["age","deposit"]].value_counts() # ## relacion entre age = Edad del cliente y el deposito
age_valores
# Out:
# age  deposit
# 32   no         1864
# 31   no         1790
# 33   no         1762
# 34   no         1732
# 35   no         1685
#                 ...
# 85   no            1
# 87   no            1
# 94   no            1
# 95   no            1
#      yes           1
# Name: count, Length: 148, dtype: int64

# %% [markdown]
#  **<font color="DeepPink">Hay que explorar dentro de los datos de la relacion entre estas caracteristicas mas importantes del modelo y la variable objetivo, para entregarle a Marketing las primeras conclusiones</font>**

# %% [markdown]
# # **<font color="DeepPink">07 - Save Models</font>**
#
# <h5 align="center"><b>
# <font color="DeepPink">
# <b><mark>Setup</mark> ▶ <mark>Compare Models</mark> ▶ <mark>Analyze Model</mark> ▶ <mark>Prediction</mark> ▶ <mark>Save Model</mark>

# %% [markdown]
# <p align="justify">
# 👀 Finalmente, se puede guardar todo el pipeline para su uso posterior, utilizando la función <code>save_model</code>.

# %%
save_model(best, 'my_first_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['age', 'balance', 'day',
#                                               'duration', 'campaign', 'pdays',
#                                               'previous'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep...
#                   LGBMClassifier(boosting_type='gbdt', class_weight=None,
# ...

# %% [markdown]
# ●	La librería pickle se utiliza para poder serializar el modelo de clasificación, es decir, grabarlo en un archivo con extensión pkl y que ese archivo contenga al modelo.

# %% [markdown]
# ●	Y por último, la librería os para poder interactuar en el proceso de grabación y lectura del archivo pkl.

# %%
loaded_best_pipeline = load_model('my_first_pipeline')
loaded_best_pipeline
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(exclude=None, include=None,
#                                                transformer=LabelEncoder())),
#                 ('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['age', 'balance', 'day',
#                                              'duration', 'campaign', 'pdays',
#                                              'previous'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_valu...
#                  LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
# ...

# %% [markdown]
#  # **<font color="DeepPink">Conclusiones</font>**

# %% [markdown]
# <p align="justify">
# 👀 En este colab nosotros:
# <br><br>
# ✅ Instalamos <code>PyCaret</code> y utilizamos un conjunto de datos de prueba de la biblioteca.
# <br>
# ✅ Definimos un <code>WorkFlow</code>.
# <br>
# ✅ Hicimos el <code>setup</code>.
# <br>
# ✅ Comparamos los modelos.
# <br>
# ✅ Analizamos los modelos, con gráficos y evaluando.
# <br>
# ✅ Hicimos la predicción del modelo.
# <br>
# ✅ Grabamos el modelo para volver a usarlo.

# %% [markdown]
# <br>
# <br>
# <p align="center"><b>
# 💗
# <font color="DeepPink">
# Hemos llegado al final de nuestro colab, a seguir codeando...
# </font>
# </p>
