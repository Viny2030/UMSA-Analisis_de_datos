# %% [markdown]
# <a href="https://colab.research.google.com/github/Viny2030/UMSA-Analisis_de_datos/blob/main/pc_01_clasificacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo](https://github.com/cristiandarioortegayubro/BA/blob/main/PyCaret.png?raw=true)

# %% [markdown]
# https://pycaret.org

# %% [markdown]
# # **Conjunto de datos de PyCaret para modelar**

# %% [markdown]
# ## **Instalando PyCaret**

# %%
# !pip install pycaret

# %% [markdown]
# ## **Conjuntos de datos**

# %%
from pycaret.datasets import get_data
index = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %% [markdown]
# ##**Carga de un conjunto de datos determinado**

# %% [markdown]
# ***Creación del DataFrame para un conjunto de datos determinado, como por ejemplo el conjunto de datos "credit"***

# %%
data = get_data('credit')
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1      90000    2          2         2   34      0      0      0      0
# 2      50000    2          2         1   37      0      0      0      0
# 3      50000    1          2         1   57     -1      0     -1      0
# 4      50000    1          1         2   37      0      0      0      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1      0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 2      0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 3      0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
# 4      0  ...    19394.0    19619.0    20024.0    2500.0    1815.0     657.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %%
from pycaret.classification import *

# %%
setup = setup(data, target = 'default', session_id = 123)
# Out:
# <style type="text/css">
# #T_febaf_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_febaf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_febaf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_febaf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_febaf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_febaf_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_febaf_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_febaf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_febaf_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_febaf_row1_col1" class="data row1 col1" >default</td>
#     </tr>
#     <tr>
#       <th id="T_febaf_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
modelo = compare_models()
# Out:
# <style type="text/css">
# #T_0cba2 th {
#   text-align: left;
# }
# ...

# %%
gbc = create_model('gbc')
# Out:
# <style type="text/css">
# #T_1f329_row10_col0, #T_1f329_row10_col1, #T_1f329_row10_col2, #T_1f329_row10_col3, #T_1f329_row10_col4, #T_1f329_row10_col5, #T_1f329_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1f329" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f329_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_1f329_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_1f329_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_1f329_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_1f329_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_1f329_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_1f329_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html

# %% [markdown]
# **class sklearn.ensemble.GradientBoostingClassifier**(*, loss='log_loss', learning_rate=0.1, n_estimators=100, subsample=1.0, criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0, init=None, random_state=None, max_features=None, verbose=0, max_leaf_nodes=None, warm_start=False, validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)

# %%
tune_gbc = tune_model(gbc)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      22:29:48
# Status     . . . . . . . . . . . . . . . . . .     Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Classifier
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-ea5bbe65af4b> in <cell line: 0>()
# ----> 1 tune_gbc = tune_model(gbc)
#
# /usr/local/lib/python3.11/dist-packages/pycaret/utils/generic.py in wrapper(*args, **kwargs)
#     962                 if globals_d[name] is None:
#     963                     raise ValueError(message)
# --> 964             return func(*args, **kwargs)
#     965
#     966         return wrapper
#
# ...
