# %% [markdown]
# <a href="https://colab.research.google.com/github/Viny2030/UMSA-Analisis_de_datos/blob/main/cuestionario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def ejecutar_cuestionario():
    preguntas = [
        {
            "pregunta": "¿Qué es un espacio de decisión en el contexto de la optimización?",
            "opciones": [
                "Una función matemática que queremos minimizar o maximizar.",
                "Una técnica iterativa utilizada para encontrar el óptimo de una función.",
                "El conjunto de todas las posibles soluciones o elecciones disponibles para un problema de optimización.",
                "La restricción que se aplica para limitar las soluciones posibles de un problema."
            ],
            "respuesta_correcta": 3
        },
        {
            "pregunta": "¿Cuál es el significado de  𝑥∗∈𝑋 ?",
            "opciones": [
                "x* es una operación matemática dentro del espacio X.",
                "x* es el conjunto de todas las soluciones posibles dentro de X.",
                "x* es el valor óptimo dentro del espacio de decisión X.",
                "x* es un vector con n dimensiones que representa el espacio de decisión."
            ],
            "respuesta_correcta": 3
        },
        {
            "pregunta": "¿Cuál es la función objetivo en el contexto de minimizar el tiempo de viaje en autobús desde un punto A a un punto B?",
            "opciones": [
                "La distancia total recorrida por el autobús.",
                "El tiempo total de viaje desde el punto A hasta el punto B.",
                "El costo del boleto de autobús.",
                "El número de paradas entre el punto A y el punto B."
            ],
            "respuesta_correcta": 2
        },
        {
            "pregunta": "¿Qué representa la 𝑓′(𝑥0)  al hallar el óptimo de una función?",
            "opciones": [
                "El valor máximo de la función en x0.",
                "La pendiente o tasa de cambio de la función en el punto x0.",
                "La integral de la función en el intervalo [0, x0].",
                "El valor absoluto de la función en x0."
            ],
            "respuesta_correcta": 2
        },
        {
            "pregunta": "¿Cuál de las siguientes afirmaciones es correcta respecto a los puntos críticos?",
            "opciones": [
                "Un punto crítico es siempre un mínimo local.",
                "Un punto crítico es donde la función alcanza su valor global máximo.",
                "Un punto crítico es donde la primera derivada de la función es igual a cero o no existe.",
                "Un punto crítico es donde la función es discontinua."
            ],
            "respuesta_correcta": 3
        },
        {
            "pregunta": "Una función es convexa si:",
            "opciones": [
                "Tiende a tener valores negativos.",
                "Su epígrafe es un conjunto convexo.",
                "Tiene su mínima derivada segunda igual a cero.",
                "Cruza el eje x al menos una vez."
            ],
            "respuesta_correcta": 2
        },
        {
            "pregunta": "¿Qué es la tolerancia en un método iterativo como el método de la bisección?",
            "opciones": [
                "El número de iteraciones que se realizará en el algoritmo.",
                "La capacidad del algoritmo para tolerar errores en los datos.",
                "El error mínimo aceptado entre dos iteraciones sucesivas para concluir el algoritmo.",
                "La tasa fija a la que avanza el método para encontrar la solución."
            ],
            "respuesta_correcta": 3
        },
        {
            "pregunta": "¿Qué simboliza el 𝜖  en la ecuación de Gradiente Descendiente  𝑥𝑖+1=𝑥𝑖−𝜖𝑓′(𝑥𝑖) ?",
            "opciones": [
                "El valor de la función objetivo en xi.",
                "El punto inicial para la optimización.",
                "El valor máximo de las iteraciones permitidas.",
                "El ritmo de aprendizaje o learning rate."
            ],
            "respuesta_correcta": 4
        },
        {
            "pregunta": "En el contexto de la optimización, ¿qué nos indica que una función de costo es convexa?",
            "opciones": [
                "Garantiza que el método del gradiente descendiente no encontrará el óptimo de la función de costo.",
                "Significa que la función de costo tiene un único óptimo local pero muchos óptimos globales.",
                "Implica que la función de costo puede tener puntos de inflexión.",
                "Permite asegurar que el método del gradiente descendiente convergerá al mínimo global de la función de costo."
            ],
            "respuesta_correcta": 4
        },
        {
            "pregunta": "¿Cuál es el propósito de incluir restricciones de desigualdad en un problema de optimización?",
            "opciones": [
                "Asegurar la convexidad de la función objetivo.",
                "Simplificar la función objetivo para hacerla más manejable matemáticamente.",
                "Limitar el espacio de decisión a soluciones viables o deseables para el problema.",
                "Eliminar la necesidad de métodos iterativos en la obtención de la solución óptima."
            ],
            "respuesta_correcta": 3
        }
    ]

    puntaje = 0
    for i, pregunta in enumerate(preguntas):
        print(f"\nPregunta {i + 1}: {pregunta['pregunta']}")
        for j, opcion in enumerate(pregunta['opciones']):
            print(f"{j + 1}) {opcion}")

        while True:
            try:
                respuesta = int(input("Ingresa el número de tu respuesta: "))
                if 1 <= respuesta <= len(pregunta['opciones']):
                    break
                else:
                    print(
                        "Respuesta inválida. Ingresa un número entre 1 y",
                        len(pregunta['opciones']),
                    )
            except ValueError:
                print("Entrada inválida. Ingresa un número.")

        if respuesta == pregunta['respuesta_correcta']:
            print("¡Correcto!")
            puntaje += 1
        else:
            print("Incorrecto.")
            print(
                "La respuesta correcta es:",
                pregunta['opciones'][pregunta['respuesta_correcta'] - 1],
            )  # Ajustado para mostrar la opción correcta

    print("\n--- Resultado ---")
    print("Puntaje total:", puntaje, "de", len(preguntas))


ejecutar_cuestionario()
# Out:
# Pregunta 1: ¿Qué es un espacio de decisión en el contexto de la optimización?
# 1) Una función matemática que queremos minimizar o maximizar.
# 2) Una técnica iterativa utilizada para encontrar el óptimo de una función.
# 3) El conjunto de todas las posibles soluciones o elecciones disponibles para un problema de optimización.
# 4) La restricción que se aplica para limitar las soluciones posibles de un problema.
# Ingresa el número de tu respuesta: 3
# ¡Correcto!
#
# Pregunta 2: ¿Cuál es el significado de  𝑥∗∈𝑋 ?
# 1) x* es una operación matemática dentro del espacio X.
# 2) x* es el conjunto de todas las soluciones posibles dentro de X.
# 3) x* es el valor óptimo dentro del espacio de decisión X.
# 4) x* es un vector con n dimensiones que representa el espacio de decisión.
# Ingresa el número de tu respuesta: 3
# ¡Correcto!
#
# Pregunta 3: ¿Cuál es la función objetivo en el contexto de minimizar el tiempo de viaje en autobús desde un punto A a un punto B?
# ...

# %%
def ejecutar_cuestionario():
    preguntas = [
        {
            "pregunta": "¿Qué es un espacio de decisión en el contexto de la optimización?",
            "opciones": [
                "Una función matemática que queremos minimizar o maximizar.",
                "Una técnica iterativa utilizada para encontrar el óptimo de una función.",
                "El conjunto de todas las posibles soluciones o elecciones disponibles para un problema de optimización.",
                "La restricción que se aplica para limitar las soluciones posibles de un problema."
            ],
            "respuesta_correcta": 3
        },
        {
            "pregunta": "¿Cuál es el significado de  𝑥∗∈𝑋 ?",
            "opciones": [
                "x* es una operación matemática dentro del espacio X.",
                "x* es el conjunto de todas las soluciones posibles dentro de X.",
                "x* es el valor óptimo dentro del espacio de decisión X.",
                "x* es un vector con n dimensiones que representa el espacio de decisión."
            ],
            "respuesta_correcta": 3
        },
        {
            "pregunta": "¿Cuál es la función objetivo en el contexto de minimizar el tiempo de viaje en autobús desde un punto A a un punto B?",
            "opciones": [
                "La distancia total recorrida por el autobús.",
                "El tiempo total de viaje desde el punto A hasta el punto B.",
                "El costo del boleto de autobús.",
                "El número de paradas entre el punto A y el punto B."
            ],
            "respuesta_correcta": 2
        },
        {
            "pregunta": "¿Qué representa la 𝑓′(𝑥0)  al hallar el óptimo de una función?",
            "opciones": [
                "El valor máximo de la función en x0.",
                "La pendiente o tasa de cambio de la función en el punto x0.",
                "La integral de la función en el intervalo [0, x0].",
                "El valor absoluto de la función en x0."
            ],
            "respuesta_correcta": 2
        },
        {
            "pregunta": "¿Cuál de las siguientes afirmaciones es correcta respecto a los puntos críticos?",
            "opciones": [
                "Un punto crítico es siempre un mínimo local.",
                "Un punto crítico es donde la función alcanza su valor global máximo.",
                "Un punto crítico es donde la primera derivada de la función es igual a cero o no existe.",
                "Un punto crítico es donde la función es discontinua."
            ],
            "respuesta_correcta": 3
        },
        {
            "pregunta": "Una función es convexa si:",
            "opciones": [
                "Tiende a tener valores negativos.",
                "Su epígrafe es un conjunto convexo.",
                "Tiene su mínima derivada segunda igual a cero.",
                "Cruza el eje x al menos una vez."
            ],
            "respuesta_correcta": 2
        },
        {
            "pregunta": "¿Qué es la tolerancia en un método iterativo como el método de la bisección?",
            "opciones": [
                "El número de iteraciones que se realizará en el algoritmo.",
                "La capacidad del algoritmo para tolerar errores en los datos.",
                "El error mínimo aceptado entre dos iteraciones sucesivas para concluir el algoritmo.",
                "La tasa fija a la que avanza el método para encontrar la solución."
            ],
            "respuesta_correcta": 3
        },
        {
            "pregunta": "¿Qué simboliza el 𝜖  en la ecuación de Gradiente Descendiente  𝑥𝑖+1=𝑥𝑖−𝜖𝑓′(𝑥𝑖) ?",
            "opciones": [
                "El valor de la función objetivo en xi.",
                "El punto inicial para la optimización.",
                "El valor máximo de las iteraciones permitidas.",
                "El ritmo de aprendizaje o learning rate."
            ],
            "respuesta_correcta": 4
        },
        {
            "pregunta": "En el contexto de la optimización, ¿qué nos indica que una función de costo es convexa?",
            "opciones": [
                "Garantiza que el método del gradiente descendiente no encontrará el óptimo de la función de costo.",
                "Significa que la función de costo tiene un único óptimo local pero muchos óptimos globales.",
                "Implica que la función de costo puede tener puntos de inflexión.",
                "Permite asegurar que el método del gradiente descendiente convergerá al mínimo global de la función de costo."
            ],
            "respuesta_correcta": 4
        },
        {
            "pregunta": "¿Cuál es el propósito de incluir restricciones de desigualdad en un problema de optimización?",
            "opciones": [
                "Asegurar la convexidad de la función objetivo.",
                "Simplificar la función objetivo para hacerla más manejable matemáticamente.",
                "Limitar el espacio de decisión a soluciones viables o deseables para el problema.",
                "Eliminar la necesidad de métodos iterativos en la obtención de la solución óptima."
            ],
            "respuesta_correcta": 3
        }
    ]

    puntaje = 0
    for i, pregunta in enumerate(preguntas):
        print(f"\nPregunta {i + 1}: {pregunta['pregunta']}")
        for j, opcion in enumerate(pregunta['opciones']):
            print(f"{j + 1}) {opcion}")

        while True:
            try:
                respuesta = int(input("Ingresa el número de tu respuesta: "))
                if 1 <= respuesta <= len(pregunta['opciones']):
                    break
                else:
                    print(
                        "Respuesta inválida. Ingresa un número entre 1 y",
                        len(pregunta['opciones']),
                    )
            except ValueError:
                print("Entrada inválida. Ingresa un número.")

        if respuesta == pregunta['respuesta_correcta']:
            print("¡Correcto!")
            puntaje += 1
        else:
            print("Incorrecto.")
            print(
                "La respuesta correcta es:",
                pregunta['opciones'][pregunta['respuesta_correcta'] - 1],
            )  # Ajustado para mostrar la opción correcta

    print("\n--- Resultado ---")
    print("Puntaje total:", puntaje, "de", len(preguntas))


ejecutar_cuestionario()
# Out:
# Pregunta 1: ¿Qué es un espacio de decisión en el contexto de la optimización?
# 1) Una función matemática que queremos minimizar o maximizar.
# 2) Una técnica iterativa utilizada para encontrar el óptimo de una función.
# 3) El conjunto de todas las posibles soluciones o elecciones disponibles para un problema de optimización.
# 4) La restricción que se aplica para limitar las soluciones posibles de un problema.
# Ingresa el número de tu respuesta: 3
# ¡Correcto!
#
# Pregunta 2: ¿Cuál es el significado de  𝑥∗∈𝑋 ?
# 1) x* es una operación matemática dentro del espacio X.
# 2) x* es el conjunto de todas las soluciones posibles dentro de X.
# 3) x* es el valor óptimo dentro del espacio de decisión X.
# 4) x* es un vector con n dimensiones que representa el espacio de decisión.
# Ingresa el número de tu respuesta: 3
# ¡Correcto!
#
# Pregunta 3: ¿Cuál es la función objetivo en el contexto de minimizar el tiempo de viaje en autobús desde un punto A a un punto B?
# ...

# %%
### CUESTIONARIO 01
import random  # Para aleatorizar el orden de las preguntas y opciones
from IPython.display import clear_output, display, HTML  # Para mejorar la presentación en Colab

def ejecutar_cuestionario():
    """
    Ejecuta un cuestionario de opción múltiple sobre historia de los datos y ciencia de datos.
    """

    preguntas = [
        {
            "pregunta": "¿Cuál de los siguientes eventos históricos impulsó significativamente el desarrollo de las ciencias computacionales?",
            "opciones": [
                "La invención de la imprenta.",
                "La Primera Guerra Mundial.",
                "La Segunda Guerra Mundial.",
                "El descubrimiento de los papiros del Mar Muerto."
            ],
            "respuesta_correcta": "La Segunda Guerra Mundial."  # La respuesta correcta es el texto de la opción
        },
        {
            "pregunta": "¿Qué máquina fue creada por Alan Turing y es considerada la primera computadora?",
            "opciones": [
                "Enigma",
                "Fortran",
                "Ultra",
                "Lotus 1,2,3"
            ],
            "respuesta_correcta": "Ultra"
        },
        {
            "pregunta": "¿En qué década el público general pudo acceder a las computadoras a un costo accesible y conocer Internet?",
            "opciones": [
                "Década de 1960",
                "Década de 1970",
                "Mediados de la década de 1980",
                "Año 1991"
            ],
            "respuesta_correcta": "Mediados de la década de 1980"
        },
        {
            "pregunta": "¿Qué lenguaje de programación se menciona como uno de los más usados actualmente para la ciencia de datos?",
            "opciones": [
                "Fortran",
                "Java",
                "Python",
                "SQL"
            ],
            "respuesta_correcta": "Python"
        },
        {
            "pregunta": "¿Quién acuñó el término 'data warehouse'?",
            "opciones": [
                "John Tukey",
                " Charles Dickens",
                "William H. Inmon",
                "Howard Dresner"
            ],
            "respuesta_correcta": "William H. Inmon"
        },
        {
            "pregunta": "¿Qué significa la sigla OLAP?",
            "opciones": [
                "Online Learning and Processing",
                "Online Analytical Processing",
                "Open Language for Analytical Programs",
                "Operating Language Application Program"
            ],
            "respuesta_correcta": "Online Analytical Processing"
        },
        {
            "pregunta": "Según el texto, ¿qué se necesita, además de los datos, para que un proyecto de Ciencia de Datos arroje resultados correctos?",
            "opciones": [
                "Un gran equipo de programadores.",
                "La aprobación del gobierno.",
                "Definir correctamente el problema a abordar.",
                "Hardware de última generación."
            ],
            "respuesta_correcta": "Definir correctamente el problema a abordar."
        },
        {
            "pregunta": "¿Cuál de las siguientes NO es una etapa del proceso de la jerarquía del conocimiento?",
            "opciones": [
                "Datos",
                "Información",
                "Intuición",
                "Sabiduría"
            ],
            "respuesta_correcta": "Intuición"
        },
        {
            "pregunta": "¿Qué tipo de análisis de datos busca determinar qué es probable que suceda en el futuro?",
            "opciones": [
                "Análisis descriptivo",
                "Análisis de diagnóstico",
                "Análisis predictivo",
                "Análisis prescriptivo"
            ],
            "respuesta_correcta": "Análisis predictivo"
        },
        {
            "pregunta": "¿Cuál es el propósito principal del proceso ETL?",
            "opciones": [
                "Diseñar algoritmos de aprendizaje automático.",
                "Generar conjuntos de datos para el proceso de BI.",
                "Crear modelos de datos conceptuales.",
                "Gestionar la cartera de clientes."
            ],
            "respuesta_correcta": "Generar conjuntos de datos para el proceso de BI."
        }
    ]

    puntaje = 0  # Inicializa el puntaje del usuario
    random.shuffle(preguntas)  # Mezcla el orden de las preguntas

    for i, pregunta in enumerate(preguntas):  # Itera sobre cada pregunta
        clear_output(wait=True)  # Limpia la salida anterior en Colab
        display(HTML(f"<h2>Pregunta {i + 1}</h2>"))  # Muestra el número de la pregunta como un encabezado
        print(pregunta["pregunta"])  # Imprime el texto de la pregunta
        opciones_mostradas = pregunta["opciones"][:]  # Crea una copia de las opciones para no modificarlas
        random.shuffle(opciones_mostradas)  # Mezcla el orden de las opciones

        mapa_opciones = {}  # Diccionario para mapear el número de opción mostrado al texto de la opción
        for j, opcion in enumerate(opciones_mostradas):  # Itera sobre las opciones mezcladas
            print(f"{j + 1}) {opcion}")  # Imprime el número y el texto de la opción
            mapa_opciones[j + 1] = opcion  # Asocia el número de la opción con su texto

        while True:  # Bucle para obtener una respuesta válida del usuario
            try:
                respuesta_usuario = int(input("Ingresa el número de tu respuesta: "))  # Obtiene la respuesta del usuario
                if 1 <= respuesta_usuario <= len(opciones_mostradas):  # Verifica si la respuesta está dentro del rango válido
                    break  # Sale del bucle si la respuesta es válida
                else:
                    print(
                        "Respuesta inválida. Ingresa un número entre 1 y",
                        len(opciones_mostradas),
                    )
            except ValueError:  # Captura la excepción si el usuario ingresa algo que no es un número
                print("Entrada inválida. Ingresa un número.")

        respuesta_usuario_texto = mapa_opciones[respuesta_usuario]  # Obtiene el texto de la opción elegida por el usuario
        if respuesta_usuario_texto == pregunta["respuesta_correcta"]:  # Compara la respuesta del usuario con la respuesta correcta
            display(HTML("<p style='color:green;'>¡Correcto!</p>"))  # Muestra "¡Correcto!" en verde
            puntaje += 1  # Incrementa el puntaje
        else:
            display(HTML("<p style='color:red;'>Incorrecto.</p>"))  # Muestra "Incorrecto." en rojo
            # Si decides mostrar la respuesta correcta en algún momento, descomenta la siguiente línea:
            # print("La respuesta correcta es:", pregunta["respuesta_correcta"])
        input("Presiona Enter para continuar...")  # Pausa para que el usuario vea el resultado

    clear_output(wait=True)  # Limpia la pantalla antes de mostrar el resultado final
    display(HTML("<h1>Resultado Final</h1>"))  # Muestra el título "Resultado Final"
    print("Puntaje total:", puntaje, "de", len(preguntas))  # Imprime el puntaje final

ejecutar_cuestionario()  # Llama a la función para ejecutar el cuestionario
# Out:
# <h2>Pregunta 1</h2>
# ¿Qué significa la sigla OLAP?
# 1) Online Learning and Processing
# 2) Operating Language Application Program
# 3) Open Language for Analytical Programs
# 4) Online Analytical Processing
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-359e7e1916d2> in <cell line: 0>()
#     152     print("Puntaje total:", puntaje, "de", len(preguntas))  # Imprime el puntaje final
#     153
# --> 154 ejecutar_cuestionario()  # Llama a la función para ejecutar el cuestionario
#
# <ipython-input-8-359e7e1916d2> in ejecutar_cuestionario()
#     127         while True:  # Bucle para obtener una respuesta válida del usuario
#     128             try:
# --> 129                 respuesta_usuario = int(input("Ingresa el número de tu respuesta: "))  # Obtiene la respuesta del usuario
# ...

# %%
### CUESTIONARIO 02

import random
from IPython.display import clear_output, display, HTML

def ejecutar_cuestionario():
    preguntas = [
        {
            "pregunta": "En una organización moderna, ¿qué se prioriza?",
            "opciones": [
                "La ejecución perfecta de tareas individuales.",
                "El cumplimiento estricto de las normas internas.",
                "La creación de valor en equipo para el cliente.",
                "La competencia entre departamentos para obtener recursos."
            ],
            "respuesta_correcta": "La creación de valor en equipo para el cliente."
        },
        {
            "pregunta": "¿Cuál es una característica de una organización moderna?",
            "opciones": [
                "Estructuras organizacionales verticales.",
                "Aislamiento entre departamentos.",
                "Énfasis en el control jerárquico.",
                "Cultura organizacional que incentiva la innovación."
            ],
            "respuesta_correcta": "Cultura organizacional que incentiva la innovación."
        },
        {
            "pregunta": "¿Qué tipo de pensamiento se impone en la gestión de la organización moderna?",
            "opciones": [
                "Pensamiento analítico",
                "Pensamiento deductivo",
                "Pensamiento sistémico",
                "Pensamiento lineal"
            ],
            "respuesta_correcta": "Pensamiento sistémico"
        },
        {
            "pregunta": "¿Cuál de las siguientes NO es una etapa del proceso administrativo según el texto?",
            "opciones": [
                "Planificación",
                "Organización",
                "Control",
                "Delegación"
            ],
            "respuesta_correcta": "Delegación"
        },
        {
            "pregunta": "¿Qué caracteriza al liderazgo 'Laissez-faire'?",
            "opciones": [
                "Control estricto de las actividades de los empleados.",
                "Enfoque exclusivo en el cumplimiento de tareas.",
                "Inspiración y entusiasmo constante del líder hacia el equipo.",
                "Autonomía y libertad para que los miembros del equipo trabajen por su cuenta."
            ],
            "respuesta_correcta": "Autonomía y libertad para que los miembros del equipo trabajen por su cuenta."
        },
        {
            "pregunta": "¿Qué busca la Gestión Lean?",
            "opciones": [
                "Maximizar la producción a cualquier costo.",
                "Incrementar los desperdicios para estimular la economía.",
                "Reducir los desperdicios y mejorar la eficiencia.",
                "Ignorar las necesidades del cliente para optimizar los procesos internos."
            ],
            "respuesta_correcta": "Reducir los desperdicios y mejorar la eficiencia."
        },
        {
            "pregunta": "¿Cuál de las siguientes NO es una herramienta de la Gestión Lean?",
            "opciones": [
                "Just in time",
                "Orden y limpieza (5S)",
                "Análisis FODA",
                "Poka Yoke"
            ],
            "respuesta_correcta": "Análisis FODA"
        },
        {
            "pregunta": "¿Qué implica la flexibilidad de la capacidad en una organización?",
            "opciones": [
                "Mantener la producción constante sin importar la demanda.",
                "Limitar la diversidad de productos o servicios ofrecidos.",
                "Adaptar rápidamente los niveles de producción a las necesidades de la demanda.",
                "Priorizar la antigüedad del personal sobre la adaptabilidad."
            ],
            "respuesta_correcta": "Adaptar rápidamente los niveles de producción a las necesidades de la demanda."
        },
        {
            "pregunta": "¿Cuál es el objetivo principal del Cuadro de Mando Integral?",
            "opciones": [
                "Maximizar las ganancias financieras a corto plazo.",
                "Controlar estrictamente el comportamiento de los empleados.",
                "Facilitar la gestión y el control organizacional mediante indicadores.",
                "Reducir la inversión en innovación y desarrollo."
            ],
            "respuesta_correcta": "Facilitar la gestión y el control organizacional mediante indicadores."
        },
        {
            "pregunta": "¿Qué representan los datos en la economía del conocimiento?",
            "opciones": [
                "Un gasto innecesario para las empresas.",
                "El único factor relevante para el éxito empresarial.",
                "Un activo fundamental para generar valor y riqueza.",
                "Un recurso limitado y sin importancia estratégica."
            ],
            "respuesta_correcta": "Un activo fundamental para generar valor y riqueza."
        }
    ]

    puntaje = 0
    random.shuffle(preguntas)

    for i, pregunta in enumerate(preguntas):
        clear_output(wait=True)
        display(HTML(f"<h2>Pregunta {i + 1}</h2>"))
        print(pregunta["pregunta"])
        opciones_mostradas = pregunta["opciones"][:]
        random.shuffle(opciones_mostradas)

        mapa_opciones = {}
        for j, opcion in enumerate(opciones_mostradas):
            print(f"{j + 1}) {opcion}")
            mapa_opciones[j + 1] = opcion

        while True:
            try:
                respuesta_usuario = int(input("Ingresa el número de tu respuesta: "))
                if 1 <= respuesta_usuario <= len(opciones_mostradas):
                    break
                else:
                    print(
                        "Respuesta inválida. Ingresa un número entre 1 y",
                        len(opciones_mostradas),
                    )
            except ValueError:
                print("Entrada inválida. Ingresa un número.")

        respuesta_usuario_texto = mapa_opciones[respuesta_usuario]
        if respuesta_usuario_texto == pregunta["opciones"][pregunta["respuesta_correcta"]]:
            display(HTML("<p style='color:green;'>¡Correcto!</p>"))
            puntaje += 1
        else:
            display(HTML("<p style='color:red;'>Incorrecto.</p>"))
            # Si decides mostrar la respuesta correcta en algún momento:
            # print("La respuesta correcta es:", pregunta["respuesta_correcta"])
        input("Presiona Enter para continuar...")

    clear_output(wait=True)
    display(HTML("<h1>Resultado Final</h1>"))
    print("Puntaje total:", puntaje, "de", len(preguntas))

ejecutar_cuestionario()
# Out:
# <h2>Pregunta 1</h2>
# ¿Cuál es el objetivo principal del Cuadro de Mando Integral?
# 1) Reducir la inversión en innovación y desarrollo.
# 2) Controlar estrictamente el comportamiento de los empleados.
# 3) Maximizar las ganancias financieras a corto plazo.
# 4) Facilitar la gestión y el control organizacional mediante indicadores.

# %%
## CUESTIONARIO NRO. 03

import random
from IPython.display import clear_output, display, HTML

def ejecutar_cuestionario():
    preguntas = [
        {
            "pregunta": "¿Qué intenta la Ciencia de Datos?",
            "opciones": [
                "Extraer conocimiento de un conjunto de datos.",
                "Crear aplicaciones web interactivas.",
                "Diseñar hardware para computadoras.",
                "Administrar redes de computadoras."
            ],
            "respuesta_correcta": "Extraer conocimiento de un conjunto de datos."
        },
        {
            "pregunta": "¿Cuál de los siguientes NO es un lenguaje de programación popular para la ciencia de datos?",
            "opciones": [
                "Python",
                "R",
                "Julia",
                "HTML"
            ],
            "respuesta_correcta": "HTML"
        },
        {
            "pregunta": "Según el texto, ¿qué es fundamental para el éxito de un proyecto de Ciencia de Datos?",
            "opciones": [
                "Tener el hardware más potente.",
                "Definir correctamente el problema a abordar.",
                "Usar el lenguaje de programación más reciente.",
                "Contar con un equipo grande de científicos de datos."
            ],
            "respuesta_correcta": "Definir correctamente el problema a abordar."
        },
        {
            "pregunta": "¿Cuál es la metodología que se describe como una codificación del proceso de extracción de conocimiento?",
            "opciones": [
                "ASUM-DM",
                "CRISP-DM",
                "OLAP",
                "ETL"
            ],
            "respuesta_correcta": "CRISP-DM"
        },
        {
            "pregunta": "¿Cuál es la primera etapa en la metodología CRISP-DM?",
            "opciones": [
                "Comprensión de los Datos",
                "Preparación de los Datos",
                "Comprensión del Negocio",
                "Modelado"
            ],
            "respuesta_correcta": "Comprensión del Negocio"
        },
        {
            "pregunta": "¿Qué implica la etapa de 'Evaluación' en CRISP-DM?",
            "opciones": [
                "Recopilar los datos iniciales.",
                "Limpiar y transformar los datos.",
                "Interpretar los modelos generados.",
                "Implementar el modelo en producción."
            ],
            "respuesta_correcta": "Interpretar los modelos generados."
        },
        {
            "pregunta": "¿Qué tarea implica la creación de nuevos atributos a partir de los existentes?",
            "opciones": [
                "Limpieza de datos",
                "Integración de datos",
                "Construcción de datos",
                "Formato de datos"
            ],
            "respuesta_correcta": "Construcción de datos"
        },
        {
            "pregunta": "¿Cuál de las siguientes NO es una etapa del CRISP-DM?",
            "opciones": [
                "Comprensión del Negocio",
                "Desarrollo de Software",
                "Evaluación",
                "Distribución y Presentación"
            ],
            "respuesta_correcta": "Desarrollo de Software"
        },
        {
            "pregunta": "¿Qué tipo de decisiones busca mejorar la Ciencia de Datos?",
            "opciones": [
                "Decisiones aleatorias.",
                "Decisiones basadas en la intuición.",
                "Decisiones informadas y precisas.",
                "Decisiones rápidas sin análisis."
            ],
            "respuesta_correcta": "Decisiones informadas y precisas."
        },
        {
            "pregunta": "¿Qué habilidad se menciona como importante para un Científico de Datos?",
            "opciones": [
                "Habilidad para diseñar interfaces de usuario.",
                "Habilidad para gestionar proyectos de construcción.",
                "Habilidad para comunicar conclusiones a no expertos.",
                "Habilidad para vender productos directamente."
            ],
            "respuesta_correcta": "Habilidad para comunicar conclusiones a no expertos."
        }
    ]

    puntaje = 0
    random.shuffle(preguntas)

    for i, pregunta in enumerate(preguntas):
        clear_output(wait=True)
        display(HTML(f"<h2>Pregunta {i + 1}</h2>"))
        print(pregunta["pregunta"])
        opciones_mostradas = pregunta["opciones"][:]
        random.shuffle(opciones_mostradas)

        mapa_opciones = {}
        for j, opcion in enumerate(opciones_mostradas):
            print(f"{j + 1}) {opcion}")
            mapa_opciones[j + 1] = opcion

        while True:
            try:
                respuesta_usuario = int(input("Ingresa el número de tu respuesta: "))
                if 1 <= respuesta_usuario <= len(opciones_mostradas):
                    break
                else:
                    print(
                        "Respuesta inválida. Ingresa un número entre 1 y",
                        len(opciones_mostradas),
                    )
            except ValueError:
                print("Entrada inválida. Ingresa un número.")

        respuesta_usuario_texto = mapa_opciones[respuesta_usuario]
        if respuesta_usuario_texto == pregunta["opciones"][pregunta["respuesta_correcta"]]:
            display(HTML("<p style='color:green;'>¡Correcto!</p>"))
            puntaje += 1
        else:
            display(HTML("<p style='color:red;'>Incorrecto.</p>"))
            # Si decides mostrar la respuesta correcta en algún momento:
            # print("La respuesta correcta es:", pregunta["respuesta_correcta"])
        input("Presiona Enter para continuar...")

    clear_output(wait=True)
    display(HTML("<h1>Resultado Final</h1>"))
    print("Puntaje total:", puntaje, "de", len(preguntas))

ejecutar_cuestionario()

# %%
### CUESATIONARIO 04

import random
from IPython.display import clear_output, display, HTML

def ejecutar_cuestionario():
    preguntas = [
        {
            "pregunta": "¿Cuál es el propósito del Proyecto Jupyter?",
            "opciones": [
                "Desarrollar sistemas operativos para computadoras.",
                "Crear videojuegos educativos.",
                "Desarrollar software de código abierto para la computación interactiva.",
                "Diseñar hardware para teléfonos móviles."
            ],
            "respuesta_correcta": "Desarrollar software de código abierto para la computación interactiva."
        },
        {
            "pregunta": "¿Qué lenguajes de programación soporta Jupyter?",
            "opciones": [
                "Solo Python.",
                "Solo Julia, Python y R.",
                "Más de 40 lenguajes, incluyendo Julia, Python y R.",
                "C, C++ y Java."
            ],
            "respuesta_correcta": "Más de 40 lenguajes, incluyendo Julia, Python y R."
        },
        {
            "pregunta": "¿Qué tipo de aplicación es Jupyter Notebook?",
            "opciones": [
                "Un sistema operativo.",
                "Una aplicación web.",
                "Un procesador de textos.",
                "Un programa de diseño gráfico."
            ],
            "respuesta_correcta": "Una aplicación web."
        },
        {
            "pregunta": "¿Cuál de las siguientes NO es una función de Jupyter Notebook?",
            "opciones": [
                "Creación de documentos con código y texto.",
                "Edición de video.",
                "Visualización de datos.",
                "Modelado estadístico."
            ],
            "respuesta_correcta": "Edición de video."
        },
        {
            "pregunta": "¿Qué es JupyterLab?",
            "opciones": [
                "Un lenguaje de programación.",
                "Un sistema de gestión de bases de datos.",
                "Un entorno de desarrollo interactivo basado en web para Jupyter.",
                "Un programa de correo electrónico."
            ],
            "respuesta_correcta": "Un entorno de desarrollo interactivo basado en web para Jupyter."
        },
        {
            "pregunta": "¿Qué es Google Colab?",
            "opciones": [
                "Un sistema operativo de Google.",
                "Un navegador web de Google.",
                "Un entorno gratuito de Jupyter Notebook que se ejecuta en la nube.",
                "Un servicio de almacenamiento en la nube de Google."
            ],
            "respuesta_correcta": "Un entorno gratuito de Jupyter Notebook que se ejecuta en la nube."
        },
        {
            "pregunta": "¿Qué tipo de celdas se utilizan en Google Colab para escribir y ejecutar código Python?",
            "opciones": [
                "Celdas de texto.",
                "Celdas de código.",
                "Celdas Markdown.",
                "Celdas LaTeX."
            ],
            "respuesta_correcta": "Celdas de código."
        },
        {
            "pregunta": "¿Qué lenguaje se utiliza para escribir ecuaciones en las celdas de texto de Colab?",
            "opciones": [
                "HTML",
                "CSS",
                "LaTeX",
                "JavaScript"
            ],
            "respuesta_correcta": "LaTeX"
        },
        {
            "pregunta": "¿Qué función permite buscar ejemplos de código en Colab?",
            "opciones": [
                "Índice",
                "Archivos",
                "Fragmentos de código",
                "Tipos de celdas"
            ],
            "respuesta_correcta": "Fragmentos de código"
        },
        {
            "pregunta": "¿Qué herramienta de Colab permite sincronizar con el espacio de almacenamiento de Google Drive?",
            "opciones": [
                "Índice",
                "Archivos",
                "Fragmentos de código",
                "Tipos de celdas"
            ],
            "respuesta_correcta": "Archivos"
        }
    ]

    puntaje = 0
    random.shuffle(preguntas)

    for i, pregunta in enumerate(preguntas):
        clear_output(wait=True)
        display(HTML(f"<h2>Pregunta {i + 1}</h2>"))
        print(pregunta["pregunta"])
        opciones_mostradas = pregunta["opciones"][:]
        random.shuffle(opciones_mostradas)

        mapa_opciones = {}
        for j, opcion in enumerate(opciones_mostradas):
            print(f"{j + 1}) {opcion}")
            mapa_opciones[j + 1] = opcion

        while True:
            try:
                respuesta_usuario = int(input("Ingresa el número de tu respuesta: "))
                if 1 <= respuesta_usuario <= len(opciones_mostradas):
                    break
                else:
                    print(
                        "Respuesta inválida. Ingresa un número entre 1 y",
                        len(opciones_mostradas),
                    )
            except ValueError:
                print("Entrada inválida. Ingresa un número.")

        respuesta_usuario_texto = mapa_opciones[respuesta_usuario]
        if respuesta_usuario_texto == pregunta["opciones"][pregunta["respuesta_correcta"] - 1]:
            display(HTML("<p style='color:green;'>¡Correcto!</p>"))
            puntaje += 1
        else:
            display(HTML("<p style='color:red;'>Incorrecto.</p>"))
            # Si decides mostrar la respuesta correcta en algún momento:
            # print("La respuesta correcta es:", pregunta["respuesta_correcta"])
        input("Presiona Enter para continuar...")

    clear_output(wait=True)
    display(HTML("<h1>Resultado Final</h1>"))
    print("Puntaje total:", puntaje, "de", len(preguntas))

ejecutar_cuestionario()

# %%
### CUESTIONARIO 05

import random
from IPython.display import clear_output, display, HTML

def ejecutar_cuestionario():
    preguntas = [
        {
            "pregunta": "¿Qué tipo de software y servicios desarrolla el Proyecto Jupyter?",
            "opciones": [
                "Sistemas operativos para computadoras personales",
                "Aplicaciones de diseño gráfico",
                "Software de código abierto para la computación interactiva",
                "Juegos de video educativos"
            ],
            "respuesta_correcta": "Software de código abierto para la computación interactiva"
        },
        {
            "pregunta": "¿A qué hace referencia el nombre 'Jupyter'?",
            "opciones": [
                "A un planeta del sistema solar",
                "A los tres lenguajes de programación principales soportados: Julia, Python y R",
                "A un famoso científico del siglo XX",
                "A una empresa de tecnología"
            ],
            "respuesta_correcta": "A los tres lenguajes de programación principales soportados: Julia, Python y R"
        },
        {
            "pregunta": "¿Quién fue el creador original de IPython, el antecesor del Proyecto Jupyter?",
            "opciones": [
                "Linus Torvalds",
                "Dennis Ritchie",
                "Fernando Pérez",
                "Guido van Rossum"
            ],
            "respuesta_correcta": "Fernando Pérez"
        },
        {
            "pregunta": "¿Qué es un Jupyter Notebook?",
            "opciones": [
                "Un sistema operativo",
                "Un lenguaje de programación",
                "Una página web que contiene código, ecuaciones, visualizaciones y texto",
                "Un programa de edición de imágenes"
            ],
            "respuesta_correcta": "Una página web que contiene código, ecuaciones, visualizaciones y texto"
        },
        {
            "pregunta": "¿Cuál de las siguientes NO es una función de Jupyter Notebook?",
            "opciones": [
                "Simulación numérica",
                "Edición de video",
                "Aprendizaje automático",
                "Visualización de datos"
            ],
            "respuesta_correcta": "Edición de video"
        },
        {
            "pregunta": "¿Qué es JupyterLab?",
            "opciones": [
                "Un lenguaje de programación para ciencia de datos",
                "Un sistema de gestión de bases de datos",
                "Un entorno de desarrollo interactivo basado en web para Jupyter",
                "Un sistema de control de versiones"
            ],
            "respuesta_correcta": "Un entorno de desarrollo interactivo basado en web para Jupyter"
        },
        {
            "pregunta": "¿Qué es Google Colab?",
            "opciones": [
                "Un sistema operativo de Google",
                "Un navegador web de Google",
                "Un entorno gratuito de Jupyter Notebook que se ejecuta en la nube",
                "Un servicio de correo electrónico de Google"
            ],
            "respuesta_correcta": "Un entorno gratuito de Jupyter Notebook que se ejecuta en la nube"
        },
        {
            "pregunta": "¿Qué tipo de celdas se utilizan en Google Colab para escribir y ejecutar código?",
            "opciones": [
                "Celdas de texto",
                "Celdas de código",
                "Celdas Markdown",
                "Celdas LaTeX"
            ],
            "respuesta_correcta": "Celdas de código"
        },
        {
            "pregunta": "¿Qué lenguaje se utiliza para escribir ecuaciones en las celdas de texto de Colab?",
            "opciones": [
                "HTML",
                "CSS",
                "LaTeX",
                "JavaScript"
            ],
            "respuesta_correcta": "LaTeX"
        },
        {
            "pregunta": "¿Qué herramienta de Colab permite acceder a ejemplos de código?",
            "opciones": [
                "Índice",
                "Archivos",
                "Fragmentos de Código",
                "Tipos de Celdas"
            ],
            "respuesta_correcta": "Fragmentos de Código"
        }
    ]

    puntaje = 0
    random.shuffle(preguntas)

    for i, pregunta in enumerate(preguntas):
        clear_output(wait=True)
        display(HTML(f"<h2>Pregunta {i + 1}</h2>"))
        print(pregunta["pregunta"])
        opciones_mostradas = pregunta["opciones"][:]
        random.shuffle(opciones_mostradas)

        mapa_opciones = {}
        for j, opcion in enumerate(opciones_mostradas):
            print(f"{j + 1}) {opcion}")
            mapa_opciones[j + 1] = opcion

        while True:
            try:
                respuesta_usuario = int(input("Ingresa el número de tu respuesta: "))
                if 1 <= respuesta_usuario <= len(opciones_mostradas):
                    break
                else:
                    print(
                        "Respuesta inválida. Ingresa un número entre 1 y",
                        len(opciones_mostradas),
                    )
            except ValueError:
                print("Entrada inválida. Ingresa un número.")

        respuesta_usuario_texto = mapa_opciones[respuesta_usuario]
        if respuesta_usuario_texto == pregunta["opciones"][pregunta["respuesta_correcta"] - 1]:
            display(HTML("<p style='color:green;'>¡Correcto!</p>"))
            puntaje += 1
        else:
            display(HTML("<p style='color:red;'>Incorrecto.</p>"))
            # Si decides mostrar la respuesta correcta en algún momento:
            # print("La respuesta correcta es:", pregunta["respuesta_correcta"])
        input("Presiona Enter para continuar...")

    clear_output(wait=True)
    display(HTML("<h1>Resultado Final</h1>"))
    print("Puntaje total:", puntaje, "de", len(preguntas))

ejecutar_cuestionario()

# %%
CUESTIONARIO 06

import random
from IPython.display import clear_output, display, HTML

def ejecutar_cuestionario():
    preguntas = [
        {
            "pregunta": "¿Cuál es la función principal del Proyecto Jupyter?",
            "opciones": [
                "Desarrollar sistemas operativos para computadoras.",
                "Crear videojuegos interactivos.",
                "Desarrollar software de código abierto para la computación interactiva.",
                "Diseñar procesadores para dispositivos móviles."
            ],
            "respuesta_correcta": "Desarrollar software de código abierto para la computación interactiva."
        },
        {
            "pregunta": "¿A qué hace referencia el nombre 'Jupyter'?",
            "opciones": [
                "Un planeta del sistema solar.",
                "Los tres lenguajes de programación principales soportados: Julia, Python y R.",
                "Un famoso científico del siglo XIX.",
                "Una empresa de tecnología."
            ],
            "respuesta_correcta": "Los tres lenguajes de programación principales soportados: Julia, Python y R."
        },
        {
            "pregunta": "¿Quién fue el creador original de IPython, el precursor del Proyecto Jupyter?",
            "opciones": [
                "Linus Torvalds",
                "Guido van Rossum",
                "Fernando Pérez",
                "Bjarne Stroustrup"
            ],
            "respuesta_correcta": "Fernando Pérez"
        },
        {
            "pregunta": "¿Qué tipo de aplicación es Jupyter Notebook?",
            "opciones": [
                "Un sistema operativo.",
                "Una aplicación web.",
                "Un procesador de textos.",
                "Un programa de diseño gráfico."
            ],
            "respuesta_correcta": "Una aplicación web."
        },
        {
            "pregunta": "¿Cuál de las siguientes NO es una función de Jupyter Notebook?",
            "opciones": [
                "Creación de documentos con código y texto.",
                "Edición de video.",
                "Visualización de datos.",
                "Modelado estadístico."
            ],
            "respuesta_correcta": "Edición de video."
        },
        {
            "pregunta": "¿Qué es JupyterLab?",
            "opciones": [
                "Un lenguaje de programación.",
                "Un sistema de gestión de bases de datos.",
                "Un entorno de desarrollo interactivo basado en web para Jupyter.",
                "Un sistema de control de versiones."
            ],
            "respuesta_correcta": "Un entorno de desarrollo interactivo basado en web para Jupyter."
        },
        {
            "pregunta": "¿Qué es Google Colab?",
            "opciones": [
                "Un sistema operativo de Google.",
                "Un navegador web de Google.",
                "Un entorno gratuito de Jupyter Notebook que se ejecuta en la nube.",
                "Un servicio de correo electrónico de Google."
            ],
            "respuesta_correcta": "Un entorno gratuito de Jupyter Notebook que se ejecuta en la nube."
        },
        {
            "pregunta": "¿Qué tipo de celdas se utilizan en Google Colab para escribir y ejecutar código Python?",
            "opciones": [
                "Celdas de texto.",
                "Celdas de código.",
                "Celdas Markdown.",
                "Celdas LaTeX."
            ],
            "respuesta_correcta": "Celdas de código."
        },
        {
            "pregunta": "¿Qué lenguaje se utiliza para escribir ecuaciones en las celdas de texto de Colab?",
            "opciones": [
                "HTML",
                "CSS",
                "LaTeX",
                "JavaScript"
            ],
            "respuesta_correcta": "LaTeX"
        },
        {
            "pregunta": "¿Qué herramienta de Colab permite buscar ejemplos de código?",
            "opciones": [
                "Índice",
                "Archivos",
                "Fragmentos de Código",
                "Tipos de Celdas"
            ],
            "respuesta_correcta": "Fragmentos de Código"
        }
    ]

    puntaje = 0
    random.shuffle(preguntas)

    for i, pregunta in enumerate(preguntas):
        print(f"\nPregunta {i + 1}: {pregunta['pregunta']}")
        for j, opcion in enumerate(pregunta['opciones']):
            print(f"{j + 1}) {opcion}")

        while True:
            try:
                respuesta = int(input("Ingresa el número de tu respuesta: "))
                if 1 <= respuesta <= len(pregunta['opciones']):
                    break
                else:
                    print("Respuesta inválida. Ingresa un número entre 1 y", len(pregunta['opciones']))
            except ValueError:
                print("Entrada inválida. Ingresa un número.")

        if respuesta - 1 == pregunta['respuesta_correcta']:
            print("¡Correcto!")
            puntaje += 1
        else:
            print("Incorrecto.")
            print("La respuesta correcta es:", pregunta['opciones'][pregunta['respuesta_correcta']])

    print("\n--- Resultado ---")
    print("Puntaje total:", puntaje, "de", len(preguntas))

ejecutar_cuestionario()

# %%
###CUESTIONARIO 07

preguntas_eda_preprocesamiento = [
    {
        "pregunta": "¿Cuál es el objetivo principal del Análisis Exploratorio de Datos (EDA)?",
        "opciones": {
            "a": "Construir modelos predictivos complejos.",
            "b": "Identificar patrones, tendencias y problemas de calidad en los datos.",
            "c": "Dividir el conjunto de datos en entrenamiento y prueba.",
            "d": "Aplicar algoritmos de aprendizaje automático."
        },
        "respuesta": "b"
    },
    {
        "pregunta": "Según el texto, ¿qué porcentaje del tiempo dedican típicamente los Científicos de Datos a comprender y preparar los datos?",
        "opciones": {
            "a": "20%",
            "b": "50%",
            "c": "80%",
            "d": "95%"
        },
        "respuesta": "c"
    },
    {
        "pregunta": "¿Cuál de las siguientes NO es una tarea comúnmente realizada durante el preprocesamiento de datos?",
        "opciones": {
            "a": "Manejo de valores faltantes.",
            "b": "Eliminación de valores atípicos.",
            "c": "Selección del algoritmo de aprendizaje automático.",
            "d": "Codificación de características."
        },
        "respuesta": "c"
    },
    {
        "pregunta": "¿Qué técnica de visualización se menciona para identificar la distribución de una variable?",
        "opciones": {
            "a": "Scatter plot.",
            "b": "Mapa de calor (heatmap).",
            "c": "Histograma.",
            "d": "Gráfico de dispersión (joint plot)."
        },
        "respuesta": "c"
    },
    {
        "pregunta": "¿Cuál es el propósito principal de dividir el conjunto de datos en entrenamiento y prueba/validación?",
        "opciones": {
            "a": "Aumentar la cantidad total de datos disponibles.",
            "b": "Evaluar la capacidad de generalización del modelo a datos no vistos.",
            "c": "Facilitar la visualización de los datos.",
            "d": "Mejorar la velocidad de entrenamiento del modelo."
        },
        "respuesta": "b"
    },
    {
        "pregunta": "Cuando se encuentran valores faltantes en un conjunto de datos, ¿cuál de las siguientes NO es una estrategia mencionada para manejarlos?",
        "opciones": {
            "a": "Eliminar las filas con valores faltantes.",
            "b": "Completar los valores faltantes manualmente.",
            "c": "Ignorar los valores faltantes durante el modelado.",
            "d": "Completar los valores faltantes usando la media, mediana o moda."
        },
        "respuesta": "c"
    },
    {
        "pregunta": "¿Qué tipo de gráfico es útil para visualizar valores atípicos a través de cuartiles?",
        "opciones": {
            "a": "Gráfico de líneas.",
            "b": "Gráfico de barras.",
            "c": "Gráfico de caja (boxplot).",
            "d": "Gráfico circular."
        },
        "respuesta": "c"
    },
    {
        "pregunta": "¿Cuál es el objetivo de las técnicas de codificación en el preprocesamiento de datos?",
        "opciones": {
            "a": "Reducir la dimensionalidad del conjunto de datos.",
            "b": "Convertir variables categóricas en un formato numérico que los modelos puedan entender.",
            "c": "Estandarizar la escala de las variables numéricas.",
            "d": "Eliminar el ruido y las inconsistencias de los datos."
        },
        "respuesta": "b"
    },
    {
        "pregunta": "¿Qué método de escalado de características busca que todas las características estén al mismo nivel de magnitud?",
        "opciones": {
            "a": "Codificación one-hot.",
            "b": "Codificación por etiquetas (label encoding).",
            "c": "Escalado estándar (StandardScaler) y escalado Min-Max (MinMaxScaler).",
            "d": "Transformación logarítmica."
        },
        "respuesta": "c"
    },
    {
        "pregunta": "¿Cuál es el propósito de la división de columnas en el preprocesamiento de datos?",
        "opciones": {
            "a": "Reducir la cantidad total de columnas en el dataframe.",
            "b": "Mejorar la eficiencia del almacenamiento de datos.",
            "c": "Crear nuevas columnas a partir de columnas existentes, facilitando la comprensión de los datos por los algoritmos.",
            "d": "Asegurar que todas las columnas tengan el mismo tipo de datos."
        },
        "respuesta": "c"
    }
]

# Puedes iterar sobre la lista para imprimir cada pregunta y sus opciones
for i, pregunta_data in enumerate(preguntas_eda_preprocesamiento):
    print(f"Pregunta {i+1}: {pregunta_data['pregunta']}")
    for opcion, texto in pregunta_data['opciones'].items():
        print(f"  {opcion}) {texto}")
    print(f"  Respuesta correcta: {pregunta_data['respuesta']}")
    print("-" * 30)

# %%
### CUESTIONARIO 08

preguntas_machine_learning = [
    {
        "pregunta": "¿Cuál de las siguientes opciones describe mejor el aprendizaje automático (Machine Learning)?",
        "opciones": {
            "a": "Programar explícitamente computadoras para realizar tareas específicas.",
            "b": "Construir algoritmos que pueden aprender patrones de los datos sin ser programados explícitamente.",
            "c": "Desarrollar sistemas de inteligencia artificial que replican la conciencia humana.",
            "d": "Crear bases de datos para almacenar grandes volúmenes de información."
        },
        "respuesta": "b"
    },
    {
        "pregunta": "¿Cuál de los siguientes NO es un tipo de aprendizaje automático mencionado en el texto?",
        "opciones": {
            "a": "Aprendizaje supervisado.",
            "b": "Aprendizaje no supervisado.",
            "c": "Aprendizaje por refuerzo.",
            "d": "Aprendizaje conjunto."
        },
        "respuesta": "c"
    },
    {
        "pregunta": "En el aprendizaje supervisado, ¿qué tipo de datos se utilizan para entrenar el algoritmo?",
        "opciones": {
            "a": "Datos sin etiquetas.",
            "b": "Datos con etiquetas que incluyen la variable objetivo.",
            "c": "Datos generados aleatoriamente.",
            "d": "Datos de imágenes y audio."
        },
        "respuesta": "b"
    },
    {
        "pregunta": "¿Cuál es el objetivo principal del aprendizaje no supervisado?",
        "opciones": {
            "a": "Predecir una variable objetivo específica.",
            "b": "Clasificar datos en categorías predefinidas.",
            "c": "Descubrir patrones y estructuras ocultas en los datos, como la agrupación de datos similares.",
            "d": "Optimizar la toma de decisiones en tiempo real."
        },
        "respuesta": "c"
    },
    {
        "pregunta": "¿Qué es un modelo de aprendizaje automático?",
        "opciones": {
            "a": "Un conjunto de datos sin procesar.",
            "b": "Un programa de computadora que ejecuta instrucciones.",
            "c": "Un algoritmo que aprende patrones de los datos para generar predicciones.",
            "d": "Una herramienta de visualización de datos."
        },
        "respuesta": "c"
    },
    {
        "pregunta": "¿Cuál es la función principal de la biblioteca Scikit-Learn (sklearn)?",
        "opciones": {
            "a": "Visualización de datos.",
            "b": "Desarrollo de interfaces de usuario.",
            "c": "Procesamiento de datos y entrenamiento de algoritmos de aprendizaje automático.",
            "d": "Gestión de bases de datos."
        },
        "respuesta": "c"
    },
    {
        "pregunta": "¿Qué problema ocurre cuando un modelo de aprendizaje automático aprende demasiado bien los datos de entrenamiento pero no generaliza bien a datos nuevos?",
        "opciones": {
            "a": "Subajuste (Underfitting).",
            "b": "Sobreajuste (Overfitting).",
            "c": "Correlación.",
            "d": "Dispersión."
        },
        "respuesta": "b"
    },
    {
        "pregunta": "¿Qué técnica se utiliza para evaluar el rendimiento de un modelo de aprendizaje automático en diferentes subconjuntos de los datos?",
        "opciones": {
            "a": "Análisis de componentes principales (PCA).",
            "b": "Validación cruzada (Cross-validation).",
            "c": "Codificación one-hot.",
            "d": "Escalado Min-Max."
        },
        "respuesta": "b"
    },
    {
        "pregunta": "¿Cuál de las siguientes NO es una consideración ética importante en el desarrollo de algoritmos de aprendizaje automático?",
        "opciones": {
            "a": "Asegurar la trazabilidad de los datos.",
            "b": "Evitar resultados injustos y sesgos.",
            "c": "Maximizar la complejidad del modelo.",
            "d": "Manejar la evidencia no concluyente con cuidado."
        },
        "respuesta": "c"
    },
    {
        "pregunta": "¿Qué implica la 'interpretación de un modelo de aprendizaje automático'?",
        "opciones": {
            "a": "Ignorar los resultados del modelo.",
            "b": "Comprender cómo el modelo llega a sus predicciones y qué variables son más influyentes.",
            "c": "Reemplazar el modelo con uno más simple.",
            "d": "Utilizar el modelo sin ninguna evaluación."
        },
        "respuesta": "b"
    }
]

# Imprimir las preguntas y opciones
for i, pregunta_data in enumerate(preguntas_machine_learning):
    print(f"Pregunta {i + 1}: {pregunta_data['pregunta']}")
    for opcion, texto in pregunta_data['opciones'].items():
        print(f"  {opcion}) {texto}")
    print(f"  Respuesta correcta: {pregunta_data['respuesta']}")
    print("-" * 20)
