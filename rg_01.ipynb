# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/BA/blob/main/rg_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://scikit-learn.org/stable/_static/scikit-learn-logo-small.png)

# %% [markdown]
# # **Regresión**

# %% [markdown]
# # ***Arbol de Regresión***

# %% [markdown]
# ***Supóngase que el departamento de ventas de una empresa quiere estudiar la influencia que tiene la publicidad a través de distintos canales sobre el número de ventas de un producto. Se dispone de un conjunto de datos que contiene los ingresos (en millones) conseguido por ventas en 200 regiones, así como la cantidad de presupuesto, también en millones, destinado a anuncios por radio, TV y periódicos en cada una de ellas.***

# %% [markdown]
# ## **Bibliotecas**

# %% [markdown]
# ### **Instalando bibliotecas**

# %%
# !pip install plotly --upgrade
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Collecting plotly
#   Downloading plotly-6.7.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly) (2.21.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (26.2)
# Downloading plotly-6.7.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 39.8 MB/s eta 0:00:00
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# Successfully installed plotly-6.7.0

# %% [markdown]
# ### **Análisis de datos**

# %%
import numpy as np
import pandas as pd
from math import sqrt

# %% [markdown]
# ### **Gráficos**

# %%
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Preprocesado y modelado**

# %% [markdown]
# #### **Con Scikit-learn**

# %%
import sklearn
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz
from sklearn.tree import export_text
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## **Conjunto de Datos**

# %%
url = "https://raw.githubusercontent.com/Viny2030/UMSA-Analisis_de_datos/refs/heads/main/publicidad_multiple.csv"

# %% [markdown]
# ## ***Dataframe***

# %%
datos = pd.read_csv(url, index_col = 0)

# %%
datos.head(10)
# Out:
#    ventas  radio    tv  periodico
# 0   230.1   37.8  69.2       22.1
# 1    44.5   39.3  45.1       10.4
# 2    17.2   45.9  69.3        9.3
# 3   151.5   41.3  58.5       18.5
# 4   180.8   10.8  58.4       12.9
# 5     8.7   48.9  75.0        7.2
# 6    57.5   32.8  23.5       11.8
# 7   120.2   19.6  11.6       13.2
# 8     8.6    2.1   1.0        4.8
# 9   199.8    2.6  21.2       10.6

# %%
datos.to_csv("publicidad_multiple.csv")

# %% [markdown]
# ## **Relación entre variables**

# %% [markdown]
# ***El primer paso a la hora de establecer un modelo lineal múltiple es estudiar la relación que existe entre variables. Esta información es crítica a la hora de identificar cuáles pueden ser los mejores predictores para el modelo, y para detectar colinealidad entre predictores. A modo complementario, es recomendable representar la distribución de cada variable mediante histogramas.***

# %%
corr_matrix = round(datos.corr(),3)

# %% [markdown]
# ### **Matriz de correlaciones**

# %%
px.imshow(corr_matrix,
          title = "Matriz de correlacion",
          text_auto = True,
          template = "gridon",
          labels={"color":"Coeficiente"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="71b5a40d-aaf4-49e8-a300-ad4a9baedbcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("71b5a40d-aaf4-49e8-a300-ad4a9baedbcb")) {                    Plotly.newPlot(                        "71b5a40d-aaf4-49e8-a300-ad4a9baedbcb",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["ventas","radio","tv","periodico"],"y":["ventas","radio","tv","periodico"],"z":{"dtype":"f8","bdata":"AAAAAAAA8D8pXI\u002fC9SisP8l2vp8aL60\u002foBov3SQG6T8pXI\u002fC9SisPwAAAAAAAPA\u002fDi2yne+n1j8730+Nl27iP8l2vp8aL60\u002fDi2yne+n1j8AAAAAAADwP8l2vp8aL80\u002foBov3SQG6T8730+Nl27iP8l2vp8aL80\u002fAAAAAAAA8D8=","shape":"4, 4"},"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003eCoeficiente: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"scaleanchor":"y","constrain":"domain"},"yaxis":{"anchor":"x","domain":[0.0,1.0],"autorange":"reversed","constrain":"domain"},"coloraxis":{"colorbar":{"title":{"text":"Coeficiente"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]},"title":{"text":"Matriz de correlacion"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('71b5a40d-aaf4-49e8-a300-ad4a9baedbcb');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>
# </body>
# </html>

# %% [markdown]
# ### 📊 Análisis de Correlación: Impacto publicitario
#
# Esta matriz evalúa la relación lineal entre los distintos canales de inversión y la variable objetivo. Los colores indican la fuerza de la relación.
#
# | Relación Evaluada | Coeficiente (r) | Interpretación Analítica |
# | :--- | :---: | :--- |
# | **Ventas vs. Periódico** | <span style="color: #28a745;">**0.782**</span> | 🟢 <span style="color: #28a745;">**Fuerte correlación positiva.**</span> Es la variable predictora principal. Un aumento en la inversión en este medio se asocia fuertemente con un incremento en ventas. |
# | **Ventas vs. TV** | <span style="color: #dc3545;">**0.057**</span> | 🔴 <span style="color: #dc3545;">**Correlación nula.**</span> La inversión en televisión no presenta una relación lineal que explique el comportamiento de las ventas. |
# | **Ventas vs. Radio** | <span style="color: #dc3545;">**0.055**</span> | 🔴 <span style="color: #dc3545;">**Correlación nula.**</span> Impacto estadísticamente insignificante para la predicción directa de ventas. |
# | **Periódico vs. Radio** | <span style="color: #fd7e14;">**0.576**</span> | 🟠 <span style="color: #fd7e14;">**Correlación moderada.**</span> Sugiere cierta colinealidad; es común que las campañas combinen presupuesto en ambos canales simultáneamente. |
# | **Radio vs. TV** | <span style="color: #ffc107;">**0.354**</span> | 🟡 <span style="color: #ffc107;">**Correlación débil.**</span> Existe una relación marginal al momento

# %% [markdown]
# ### **Gráfico de distribución para cada variable numérica**

# %%
datos.columns
# Out:
# Index(['ventas', 'radio', 'tv', 'periodico'], dtype='object')

# %%
datos.columns[1:4]
# Out:
# Index(['radio', 'tv', 'periodico'], dtype='object')

# %%
for i in datos.columns[1:4]:
  fig = px.scatter(datos,
                   x = i,
                   y = datos.ventas,
                   template = "gridon",
                   title = i)

  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="8ee8bbff-e9a5-4c65-9787-46ed23f99320" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8ee8bbff-e9a5-4c65-9787-46ed23f99320")) {                    Plotly.newPlot(                        "8ee8bbff-e9a5-4c65-9787-46ed23f99320",                        [{"hovertemplate":"radio=%{x}\u003cbr\u003eventas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1F77B4","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"\...\\..."},"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzPDbEAAAAAAAEBGQDMzMzMzMzFAAAAAAADwYkCamZmZmZlmQGZmZmZmZiFAAAAAAADATEDNzMzMzAxeQDMzMzMzMyFAmpmZmZn5aEBmZmZmZoZQQGZmZmZm1mpAzczMzMzMN0AAAAAAAGBYQDMzMzMzg2lAzczMzMxsaEAzMzMzM\\..."},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"radio"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"ventas"}},"legend":{"tracegroupgap":0},"title":{"text":"radio"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('8ee8bbff-e9a5-4c65-9787-46ed23f99320');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>
# </body>
# </html>
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="21a08891-4358-4268-908c-881638029b44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("21a08891-4358-4268-908c-881638029b44")) {                    Plotly.newPlot(                        "21a08891-4358-4268-908c-881638029b44",                        [{"hovertemplate":"tv=%{x}\u003cbr\u003eventas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1F77B4","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"zczMzMxMUUDNzMzMzIxGQDMzMzMzU1FAAAAAAABATUAzMzMzMzNNQAAAAAAAwFJAAAAAAACAN0AzMzMzMzMnQAAAAAAAAPA\\u002fQJqZmZmZWUNAzczMzMzM\u002fD9mZmZmZmY6QGZmZmZmpkVAAAAAAACAP0CamZmZmdlBQAAAAAAAgDJAMzMzMzPzSEBmZmZmZmZCQM3MzMzMTEFAzczMzMzMDEDNzMzMzMxDQJqZmZmZWU1AzczMzMzML0AAAAAAAABOQDMzMzMzs0RAmpmZmZmZMECamZmZmdlCQJqZmZmZmSJAZmZmZmZmNUCamZmZmVlLQM3MzMzMTDtAzczMzMzMIEBmZmZmZuY8QM3MzMzMzOw\u002fmpmZmZmZAUBmZmZmZmYkQAAAAAAAACZAMzMzMzMzO0CamZmZmVlDQDMzMzMzsz9AzczMzMxMM0DNzMzMzEw\...\..."},"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzPDbEAAAAAAAEBGQDMzMzMzMzFAAAAAAADwYkCamZmZmZlmQGZmZmZmZiFAAAAAAADATEDNzMzMzAxeQDMzMzMzMyFAmpmZmZn5aEBmZmZmZoZQQGZmZmZm1mpAzczMzMzMN0AAAAAAAGBYQDMzMzMzg2lAzczMzMxsaEAzMzMzM\\..."},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"tv"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"ventas"}},"legend":{"tracegroupgap":0},"title":{"text":"tv"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('21a08891-4358-4268-908c-881638029b44');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>
# </body>
# </html>
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="7244087d-a4d0-43c2-8628-618bdf79c93f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7244087d-a4d0-43c2-8628-618bdf79c93f")) {                    Plotly.newPlot(                        "7244087d-a4d0-43c2-8628-618bdf79c93f",                        [{"hovertemplate":"periodico=%{x}\u003cbr\u003eventas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1F77B4","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"..."},"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzPDbEAAAAAAAEBGQDMzMzMzMzFAAAAAAADwYkCamZmZmZlmQGZmZmZmZiFAAAAAAADATEDNzMzMzAxeQDMzMzMzMyFAmpmZmZn5aEBmZmZmZoZQQGZmZmZm1mpAzczMzMzMN0AAAAAAAGBYQDMzMzMzg2lAzczMzMxsaEAzMzMzM\\..."},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"periodico"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"ventas"}},"legend":{"tracegroupgap":0},"title":{"text":"periodico"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('7244087d-a4d0-43c2-8628-618bdf79c93f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>
# </body>
# </html>

# %% [markdown]
# ## ***Ajuste del modelo***

# %% [markdown]
# **Se ajusta un modelo lineal múltiple con el objetivo de predecir las ventas en función de la inversión en los tres canales de publicidad.**

# %% [markdown]
# ### **División de los datos en train y test**

# %%
X = datos[["radio","tv","periodico"]]
y = datos[["ventas"]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    train_size = 0.8,
                                                    random_state = 12345)

# %% [markdown]
# ### **Creación del modelo**

# %%
modelo = DecisionTreeRegressor(max_depth=3, random_state=0)
modelo.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=0)

# %%
modelo
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=0)

# %%
modelo.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': 0,
#  'splitter': 'best'}

# %% [markdown]
# #### ***Información del modelo***

# %%
print("Coeficiente de determinación R^2:", modelo.score(X, y))
# Out:
# Coeficiente de determinación R^2: 0.7818883644643493

# %% [markdown]
# ### **Predicción**

# %%
predicciones = modelo.predict(X = X_test)
print(predicciones[0:3,])
# Out:
# [253.48823529 132.99230769  62.77058824]

# %%
X_test["Ventas"] = y_test
X_test["Prediccion"] = predicciones
X_test.head(9)
# Out:
#      radio    tv  periodico  Ventas  Prediccion
# 52    41.7  39.6       22.6   216.4  253.488235
# 157    1.3  24.3       10.1   149.8  132.992308
# 135   47.0   8.5       11.6    48.3   62.770588
# 140   17.0  12.9       10.9    73.4   62.770588
# 56    28.1  41.4        5.5     7.3   15.830769
# 95    31.6  52.9       16.9   163.3  162.046667
# 54    28.8  15.9       20.2   262.7  253.488235
# 50     3.1  34.6       11.4   199.8  132.992308
# 17    39.6  55.8       24.4   281.4  253.488235

# %% [markdown]
# ### **Evaluacion del modelo**

# %% [markdown]
# #### **Error de la media de los cuadrados - MSE**

# %%
round(sqrt(mean_squared_error(y_test, predicciones)),3)
# Out:
# 46.699

# %% [markdown]
# #### **Error de la media absoluta - MAE**

# %%
round(metrics.median_absolute_error(y_test, predicciones),3)
# Out:
# np.float64(21.172)

# %% [markdown]
# #### **Coeficiente de determinación ($R^2$)**

# %%
round(metrics.r2_score(y_test, predicciones),3)
# Out:
# 0.757

# %% [markdown]
# ## **Graficando el modelo**

# %%
print(f"Profundidad del árbol: {modelo.get_depth()}")
print(f"Número de nodos terminales: {modelo.get_n_leaves()}")
# Out:
# Profundidad del árbol: 3
# Número de nodos terminales: 8

# %%
fig, ax = plt.subplots(figsize=(12, 5))

plot = plot_tree(
            decision_tree = modelo,
            feature_names = datos.drop(columns = "ventas").columns,
            # class_names se ha eliminado porque es un árbol de regresión
            filled        = True,
            impurity      = False,
            fontsize      = 10,
            precision     = 2,
            ax            = ax)

# %% [markdown]
# ## **Importancia de predictores**

# %% [markdown]
# **La importancia de cada predictor en modelo se calcula como la reducción total (normalizada) en el criterio de división, en este caso el mse, que consigue el predictor en las divisiones en las que participa. Si un predictor no ha sido seleccionado en ninguna divisón, no se ha incluido en el modelo y por lo tanto su importancia es 0.**

# %%
importancia_predictores = pd.DataFrame(
                            {'predictor': datos.drop(columns = "ventas").columns,
                             'importancia': modelo.feature_importances_})

print(" ")
print("Importancia de los predictores en el modelo")
print("-------------------------------------------")

importancia_predictores.sort_values('importancia', ascending=False)
# Out:
#
# Importancia de los predictores en el modelo
# -------------------------------------------
#    predictor  importancia
# 2  periodico     0.866105
# 0      radio     0.133895
# 1         tv     0.000000
