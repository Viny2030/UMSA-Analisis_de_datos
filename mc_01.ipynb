# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/BA/blob/main/mc_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Análisis Exploratorio de los Datos - Matriz de Correlación**

# %% [markdown]
# # **Carga de módulos**

# %% [markdown]
# ### **Para analisis de datos**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### **Para graficos**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Carga de Datos**

# %% [markdown]
# ***Antes que nada, se genera el dataframe con los datos que se utilizaran para la matriz de correlación...***

# %%
url = "https://raw.githubusercontent.com/Viny2030/UMSA-Analisis_de_datos/refs/heads/main/recursos_humanos_II.csv"

# %%
analisis = pd.read_csv(url)
analisis.drop(columns="Unnamed: 0", inplace=True)
analisis.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
analisis.to_csv("recursos_humanos_II.csv")

# %% [markdown]
# ***Se cambian los nombres de las columnas para mejor interpretacion...***

# %%
analisis.rename(columns={"satisfaction_level":"niveldesatisfaccion",
                         "last_evaluation":"ultimaevaluacion",
                         "number_project":"numerosdeproyectos",
                         "average_montly_hours":"horasmensualespromedio",
                         "time_spend_company":"tiempoenlaempresa",
                         "Work_accident":"accidentedetrabajo",
                         "left":"abandono",
                         "promotion_last_5years":"promocionultimos5años",
                         "sales":"ventas",
                         "salary":"sueldo"}, inplace= True)

# %% [markdown]
# # **Matriz de correlación**

# %% [markdown]
# ***La correlación estadística constituye una técnica estadística que  indica si las variables están relacionadas o no lo están.***

# %% [markdown]
# ***Por ejemplo, en las variables del ingreso familiar y el gasto familiar se sabe que un aumento en los ingresos genera un aumento en los gastos, y una disminución de los ingresos, genera una disminución de los gastos. Por lo tanto, las variables ingresos y gastos están relacionadas y un cambio en cualquiera de esas variables estará acompañado por un cambio en la otra variable en el mismo sentido, o con el mismo signo.***

# %% [markdown]
# ***De la misma manera, los precios y la demanda de un producto son variables relacionadas; cuando los precios aumentan la demanda tenderá a disminuir y viceversa.***

# %% [markdown]
# ***En el caso del ingreso familiar y el gasto familiar, es fácil ver que ambos suben o bajan juntos en la misma dirección. Esto se denomina correlación positiva.***

# %% [markdown]
# ***En caso del precio y la demanda, el cambio se produce en la dirección opuesta, de modo que el aumento de una variables está acompañado de una disminución en la otra variable. Esto se conoce como correlación negativa.***

# %% [markdown]
# ## **Matriz de correlación** - Coeficiente estándar = método Pearson

# %% [markdown]
# ***La correlación de Pearson funciona bien con variables cuantitativas que tienen una distribución normal o próxima a la normal. Es más sensible a los valores extremos que las otras dos alternativas, Spearman y Kendall.***

# %% [markdown]
# ***La correlación de Spearman se emplea con variables cuantitativas (continuas o discretas). En lugar de utilizar directamente el valor de cada variable, los datos son ordenados y reemplazados por su respectivo orden ranking. Es un método no paramétrico muy utilizado cuando no se satisface la condición de normalidad necesaria para aplicar la correlación de Pearson.***

# %% [markdown]
# ***La correlación de Kendall es otra alternativa no paramétrica que, al igual que la correlación de Spearman, utiliza la ordenación de las observaciones ranking. Es recomendable cuando se dispone de pocos datos.***

# %%
pearson = analisis.corr(method="pearson", numeric_only=True)

# %%
pearson
# Out:
#                         niveldesatisfaccion  ultimaevaluacion  \
# niveldesatisfaccion                1.000000          0.105021
# ultimaevaluacion                   0.105021          1.000000
# numerosdeproyectos                -0.142970          0.349333
# horasmensualespromedio            -0.020048          0.339742
# tiempoenlaempresa                 -0.100866          0.131591
# accidentedetrabajo                 0.058697         -0.007104
# abandono                          -0.388375          0.006567
# promocionultimos5años              0.025605         -0.008684
#
#                         numerosdeproyectos  horasmensualespromedio  \
# niveldesatisfaccion              -0.142970               -0.020048
# ultimaevaluacion                  0.349333                0.339742
# numerosdeproyectos                1.000000                0.417211
# horasmensualespromedio            0.417211                1.000000
# tiempoenlaempresa                 0.196786                0.127755
# ...

# %%
plt.figure(figsize=(9,8))
sns.heatmap(pearson,
            annot=True,
            linewidths=.5)

plt.show()

# %% [markdown]
# ### Análisis Explicativo: Mapa de Calor de Correlaciones (Heatmap)
#
# | Componente / Característica | Descripción e Interpretación |
# | :--- | :--- |
# | **Tipo de Gráfico** | Es una matriz de correlación visualizada mediante un mapa de calor. Muestra el coeficiente de correlación (generalmente Pearson) entre pares de variables. |
# | **Escala de Colores** | La barra lateral derecha indica la magnitud. Los colores más claros (hacia el beige/blanco) representan correlaciones positivas fuertes (cerca de 1). Los colores más oscuros (negro/morado oscuro) representan correlaciones negativas (hacia -1). |
# | **Diagonal Principal** | Todos los valores son **1** (color más claro) porque cruzan cada variable consigo misma, lo cual representa una correlación perfecta. Es el eje de simetría del gráfico. |
# | **Correlación Negativa Destacada** | La relación más fuerte de forma inversa es entre **`abandono`** y **`niveldesatisfaccion`** ($-0.39$, el cuadro más oscuro). *Interpretación:* A menor nivel de satisfacción, mayor es la probabilidad de que el empleado abandone la empresa. |
# | **Correlaciones Positivas Destacadas** | Observamos un bloque interrelacionado: <br>• **`numerosdeproyectos`** y **`horasmensualespromedio`** ($0.42$) <br>• **`ultimaevaluacion`** y **`numerosdeproyectos`** ($0.35$) <br>• **`ultimaevaluacion`** y **`horasmensualespromedio`** ($0.34$)<br>*Interpretación:* Los empleados con más proyectos trabajan más horas promedio y, a su vez, tienden a recibir evaluaciones más altas. |
# | **Correlaciones Bajas o Nulas** | Valores cercanos a cero (ej. **`accidentedetrabajo`** con casi todas las demás, rondando $0.002$ a $0.059$). *Interpretación:* No existe una relación lineal fuerte; por ejemplo, sufrir un accidente no parece estar directamente correlacionado con el número de proyectos o las horas trabajadas. |
#
# > **Nota Teórica:** El coeficiente de correlación ($r$) varía en el intervalo $[-1, 1]$.
# > * $r > 0$: Correlación positiva (ambas variables crecen juntas).
# > * $r < 0$: Correlación negativa (una crece, la otra disminuye).
# > * $r \approx 0$: Ausencia de correlación lineal.
# > * *Importante:* Correlación no implica causalidad. Que más horas trabajadas se correlacione con mejores evaluaciones no significa necesariamente que una sea la causa directa de la otra.

# %% [markdown]
# ***Un valor positivo grande (cercano a 1) indica una fuerte correlación positiva, es decir, si el valor de una de las variables aumenta, el valor de la otra variable aumenta también.***

# %% [markdown]
# ***Un valor negativo grande (cercano a -1) indica una fuerte correlación negativa, es decir, que el valor de una de las variables disminuye al aumentar el de la otra y viceversa.***

# %% [markdown]
# ***Un valor cercano a 0 (tanto positivo como negativo) indica la ausencia de cualquier correlación entre las dos variables, y por lo tanto esas variables son independientes entre sí.***

# %% [markdown]
# ## **Ordenando los valores de la Matriz de correlación**

# %%
orden = pearson.unstack()

# %%
print(orden)
# Out:
# niveldesatisfaccion    niveldesatisfaccion       1.000000
#                        ultimaevaluacion          0.105021
#                        numerosdeproyectos       -0.142970
#                        horasmensualespromedio   -0.020048
#                        tiempoenlaempresa        -0.100866
#                                                    ...
# promocionultimos5años  horasmensualespromedio   -0.003544
#                        tiempoenlaempresa         0.067433
#                        accidentedetrabajo        0.039245
#                        abandono                 -0.061788
#                        promocionultimos5años     1.000000
# Length: 64, dtype: float64

# %%
orden = orden.sort_values()

# %%
print(orden)
# Out:
# niveldesatisfaccion    niveldesatisfaccion       1.000000
#                        ultimaevaluacion          0.105021
#                        numerosdeproyectos       -0.142970
#                        horasmensualespromedio   -0.020048
#                        tiempoenlaempresa        -0.100866
#                                                    ...
# promocionultimos5años  horasmensualespromedio   -0.003544
#                        tiempoenlaempresa         0.067433
#                        accidentedetrabajo        0.039245
#                        abandono                 -0.061788
#                        promocionultimos5años     1.000000
# Length: 64, dtype: float64

# %% [markdown]
# ### Viendo **los valores negativos**

# %%
negativos = orden[orden < 0]

# %%
print(negativos)
# Out:
# niveldesatisfaccion     numerosdeproyectos       -0.142970
#                         horasmensualespromedio   -0.020048
#                         tiempoenlaempresa        -0.100866
#                         abandono                 -0.388375
# ultimaevaluacion        accidentedetrabajo       -0.007104
#                         promocionultimos5años    -0.008684
# numerosdeproyectos      niveldesatisfaccion      -0.142970
#                         accidentedetrabajo       -0.004741
#                         promocionultimos5años    -0.006064
# horasmensualespromedio  niveldesatisfaccion      -0.020048
#                         accidentedetrabajo       -0.010143
#                         promocionultimos5años    -0.003544
# tiempoenlaempresa       niveldesatisfaccion      -0.100866
# accidentedetrabajo      ultimaevaluacion         -0.007104
#                         numerosdeproyectos       -0.004741
#                         horasmensualespromedio   -0.010143
# ...

# %% [markdown]
# ### Viendo **los valores positivos**

# %% [markdown]
# ***Elegir variables fuertemente relacionadas. Es decir, se filtran las variables cuyos valores de coeficiente de correlación sean mayores de 0,4...***

# %%
positivos = orden[orden > 0.4]

# %%
print(positivos)
# Out:
# niveldesatisfaccion     niveldesatisfaccion       1.000000
# ultimaevaluacion        ultimaevaluacion          1.000000
# numerosdeproyectos      numerosdeproyectos        1.000000
#                         horasmensualespromedio    0.417211
# horasmensualespromedio  numerosdeproyectos        0.417211
#                         horasmensualespromedio    1.000000
# tiempoenlaempresa       tiempoenlaempresa         1.000000
# accidentedetrabajo      accidentedetrabajo        1.000000
# abandono                abandono                  1.000000
# promocionultimos5años   promocionultimos5años     1.000000
# dtype: float64

# %% [markdown]
# ## **Estilo en el DataFrame** - Matriz en Pandas

# %%
pearson
# Out:
#                         niveldesatisfaccion  ultimaevaluacion  \
# niveldesatisfaccion                1.000000          0.105021
# ultimaevaluacion                   0.105021          1.000000
# numerosdeproyectos                -0.142970          0.349333
# horasmensualespromedio            -0.020048          0.339742
# tiempoenlaempresa                 -0.100866          0.131591
# accidentedetrabajo                 0.058697         -0.007104
# abandono                          -0.388375          0.006567
# promocionultimos5años              0.025605         -0.008684
#
#                         numerosdeproyectos  horasmensualespromedio  \
# niveldesatisfaccion              -0.142970               -0.020048
# ultimaevaluacion                  0.349333                0.339742
# numerosdeproyectos                1.000000                0.417211
# horasmensualespromedio            0.417211                1.000000
# tiempoenlaempresa                 0.196786                0.127755
# ...

# %%
pearson.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_e375a_row0_col0, #T_e375a_row1_col1, #T_e375a_row2_col2, #T_e375a_row3_col3, #T_e375a_row4_col4, #T_e375a_row5_col5, #T_e375a_row6_col6, #T_e375a_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e375a_row0_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_e375a_row0_col2, #T_e375a_row0_col3, #T_e375a_row0_col4, #T_e375a_row0_col6, #T_e375a_row5_col1, #T_e375a_row6_col0, #T_e375a_row6_col5, #T_e375a_row6_col7, #T_e375a_row7_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e375a_row0_col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_e375a_row0_col7 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_e375a_row1_col0, #T_e375a_row1_col3, #T_e375a_row2_col1 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_e375a_row1_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_e375a_row1_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ### Análisis Explicativo: Matriz de Correlación Estilizada (Pandas)
#
# | Componente / Característica | Descripción e Interpretación |
# | :--- | :--- |
# | **Tipo de Visualización** | Es la misma matriz de correlación (método de Pearson), pero renderizada directamente como un DataFrame de Pandas utilizando el método `.style.background_gradient()`. |
# | **Precisión Numérica** | A diferencia del mapa de calor estándar que suele redondear, esta tabla muestra los coeficientes con **seis decimales** de precisión (ej. `-0.388375` en lugar de `-0.39`). Esto es ideal para un análisis cuantitativo riguroso. |
# | **Paleta de Colores (`coolwarm`)** | Utiliza un mapa de color divergente. El **rojo intenso** marca las correlaciones positivas fuertes (como el `1.000000` de la diagonal principal). El **azul oscuro** resalta las correlaciones negativas. Los tonos celestes más claros indican una correlación cercana a `0`. |
# | **Paleta de Colores (`plasma`)** | En la celda inferior se observa la aplicación de una paleta secuencial (`plasma`). Aquí el amarillo brillante representa los valores más altos (1.0) y los tonos púrpuras oscuros representan los valores más bajos o negativos. |
# | **Confirmación de Patrones** | Se ratifican numéricamente las relaciones observadas previamente: la relación inversa más fuerte es `abandono` vs `niveldesatisfaccion` (`-0.388375`), y la

# %%
pearson.style.background_gradient(cmap="plasma")
# Out:
# <style type="text/css">
# #T_45ed0_row0_col0, #T_45ed0_row1_col1, #T_45ed0_row2_col2, #T_45ed0_row3_col3, #T_45ed0_row4_col4, #T_45ed0_row5_col5, #T_45ed0_row6_col6, #T_45ed0_row7_col7 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_45ed0_row0_col1 {
#   background-color: #46039f;
#   color: #f1f1f1;
# }
# #T_45ed0_row0_col2, #T_45ed0_row0_col3, #T_45ed0_row0_col4, #T_45ed0_row0_col6, #T_45ed0_row5_col1, #T_45ed0_row6_col0, #T_45ed0_row6_col5, #T_45ed0_row6_col7, #T_45ed0_row7_col1 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_45ed0_row0_col5 {
#   background-color: #6400a7;
#   color: #f1f1f1;
# }
# #T_45ed0_row0_col7 {
#   background-color: #3a049a;
#   color: #f1f1f1;
# }
# #T_45ed0_row1_col0, #T_45ed0_row1_col3, #T_45ed0_row2_col1 {
#   background-color: #a21d9a;
#   color: #f1f1f1;
# }
# #T_45ed0_row1_col2 {
#   background-color: #ba3388;
#   color: #f1f1f1;
# }
# #T_45ed0_row1_col4 {
#   background-color: #6f00a8;
#   color: #f1f1f1;
# }
# ...

# %%
pearson.style.background_gradient(cmap="viridis")
# Out:
# <style type="text/css">
# #T_35366_row0_col0, #T_35366_row1_col1, #T_35366_row2_col2, #T_35366_row3_col3, #T_35366_row4_col4, #T_35366_row5_col5, #T_35366_row6_col6, #T_35366_row7_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_35366_row0_col1 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_35366_row0_col2, #T_35366_row0_col3, #T_35366_row0_col4, #T_35366_row0_col6, #T_35366_row5_col1, #T_35366_row6_col0, #T_35366_row6_col5, #T_35366_row6_col7, #T_35366_row7_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_35366_row0_col5 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_35366_row0_col7 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_35366_row1_col0, #T_35366_row1_col3, #T_35366_row2_col1 {
#   background-color: #2e6d8e;
#   color: #f1f1f1;
# }
# #T_35366_row1_col2 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_35366_row1_col4 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# ...

# %%
pearson.style.background_gradient(cmap="copper")
# Out:
# <style type="text/css">
# #T_e84b8_row0_col0, #T_e84b8_row1_col1, #T_e84b8_row2_col2, #T_e84b8_row3_col3, #T_e84b8_row4_col4, #T_e84b8_row5_col5, #T_e84b8_row6_col6, #T_e84b8_row7_col7 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# #T_e84b8_row0_col1 {
#   background-color: #23160e;
#   color: #f1f1f1;
# }
# #T_e84b8_row0_col2, #T_e84b8_row0_col3, #T_e84b8_row0_col4, #T_e84b8_row0_col6, #T_e84b8_row5_col1, #T_e84b8_row6_col0, #T_e84b8_row6_col5, #T_e84b8_row6_col7, #T_e84b8_row7_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_e84b8_row0_col5 {
#   background-color: #3a2517;
#   color: #f1f1f1;
# }
# #T_e84b8_row0_col7 {
#   background-color: #1a100a;
#   color: #f1f1f1;
# }
# #T_e84b8_row1_col0, #T_e84b8_row1_col3, #T_e84b8_row2_col1 {
#   background-color: #6f462d;
#   color: #f1f1f1;
# }
# #T_e84b8_row1_col2 {
#   background-color: #885637;
#   color: #f1f1f1;
# }
# #T_e84b8_row1_col4 {
#   background-color: #432a1b;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ## **Matriz de correlación** - Coeficiente estándar = método Spearman

# %%
spearman = analisis.corr(method="spearman", numeric_only=True)

# %%
spearman
# Out:
#                         niveldesatisfaccion  ultimaevaluacion  \
# niveldesatisfaccion                1.000000          0.162407
# ultimaevaluacion                   0.162407          1.000000
# numerosdeproyectos                 0.005786          0.350399
# horasmensualespromedio             0.062000          0.342061
# tiempoenlaempresa                 -0.139428          0.161154
# accidentedetrabajo                 0.056333         -0.005767
# abandono                          -0.365842         -0.002440
# promocionultimos5años              0.022306         -0.007167
#
#                         numerosdeproyectos  horasmensualespromedio  \
# niveldesatisfaccion               0.005786                0.062000
# ultimaevaluacion                  0.350399                0.342061
# numerosdeproyectos                1.000000                0.397855
# horasmensualespromedio            0.397855                1.000000
# tiempoenlaempresa                 0.251971                0.168750
# ...

# %%
plt.figure(figsize=(9,8))
sns.heatmap(spearman,
            annot=True,
            linewidths=.5)

plt.show()

# %% [markdown]
# ## **Matriz de correlación** - Coeficiente estándar = método Kendall

# %%
kendall = analisis.corr(method="kendall", numeric_only=True)

# %%
kendall
# Out:
#                         niveldesatisfaccion  ultimaevaluacion  \
# niveldesatisfaccion                1.000000          0.113865
# ultimaevaluacion                   0.113865          1.000000
# numerosdeproyectos                 0.022077          0.266267
# horasmensualespromedio             0.051126          0.235374
# tiempoenlaempresa                 -0.110005          0.118842
# accidentedetrabajo                 0.046298         -0.004749
# abandono                          -0.300675         -0.002010
# promocionultimos5años              0.018332         -0.005903
#
#                         numerosdeproyectos  horasmensualespromedio  \
# niveldesatisfaccion               0.022077                0.051126
# ultimaevaluacion                  0.266267                0.235374
# numerosdeproyectos                1.000000                0.306987
# horasmensualespromedio            0.306987                1.000000
# tiempoenlaempresa                 0.195025                0.119466
# ...

# %%
plt.figure(figsize=(9,8))
sns.heatmap(kendall,
            annot=True,
            linewidths=.5)

plt.show()

# %% [markdown]
# ### Métodos de Correlación: Cuadro Optimizado para Lectura
#
# | Método | Tipo de Datos | Relación | Supuestos Principales | ¿Cuándo utilizarlo? |
# | :--- | :--- | :--- | :--- | :--- |
# | <span style="color:#1565C0">**Pearson**</span> ($r$) | Continuos vs. Continuos | <span style="background-color:#E3F2FD; color:#0D47A1; padding:2px 5px; border-radius:3px;">Lineal</span> | Distribución normal, sin valores atípicos. | • Medir fuerza y dirección.<br>• El cambio es proporcional.<br>• Sigue una línea recta. |
# | <span style="color:#2E7D32">**Spearman**</span> ($\rho$) | Ordinales o Continuos | <span style="background-color:#E8F5E9; color:#1B5E20; padding:2px 5px; border-radius:3px;">Monotónica</span> | No paramétrico. Usa rangos (jerarquías). | • Crecen/decrecen en conjunto.<br>• No es línea recta perfecta.<br>• Hay valores atípicos (outliers). |
# | <span style="color:#E65100">**Kendall**</span> ($\tau$) | Ordinales o Continuos | <span style="background-color:#FFF3E0; color:#E65100; padding:2px 5px; border-radius:3px;">Monotónica</span> | No paramétrico. Basado en probabilidades. | • Tienes **muestras pequeñas**.<br>• Hay muchos datos repetidos.<br>• Es más robusto que Spearman. |
# | <span style="color:#6A1B9A">**Punto-Biserial**</span> | 1 Continua vs. 1 Binaria | <span style="background-color:#F3E5F5; color:#4A148C; padding:2px 5px; border-radius:3px;">Asociación</span> | Continua con distribución normal por grupo. | • 1 Métrica (ej. salario).<br>• 1 Categoría binaria (ej. Sí/No). |
# | <span style="color:#C62828">**V de Cramér / Phi**</span>| Categóricos vs. Categóricos | <span style="background-color:#FFEBEE; color:#B71C1C; padding:2px 5px; border-radius:3px;">Asociación</span> | Basado en el estadístico Chi-cuadrado. | • Variables solo con categorías.<br>• No tienen ningún orden lógico. |
#
# > **Nota Teórica:** > * <span style="background-color:#E3F2FD; color:#0D47A1; padding:2px 5px; border-radius:3px;">Lineal</span> **(<span style="color:#1565C0">Pearson</span>):** Ritmo constante (línea recta).
# > * <span style="background-color:#E8F5E9; color:#1B5E20; padding:2px 5px; border-radius:3px;">Monotónica</span> **
