# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/BA/blob/main/sw_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://sweetviz.fbdesignpro.com/uploads/default/original/1X/d9d7b9c937a88efc6bf0b725d31ba516146a4875.png)

# %% [markdown]
# <h1><b>
# Reportes con Sweetviz

# %% [markdown]
# [sweetviz](https://pypi.org/project/sweetviz/)

# %% [markdown]
# # **Conjunto de Datos**

# %% [markdown]
# ***El conjunto de datos *SaratogaHouses* del paquete mosaicData de R contiene información sobre el precio de 1728 viviendas situadas en Saratoga County, New York, USA en el año 2006. Además del precio de las viviendas, el conjunto de datos incluye 15 variables adicionales:***

# %% [markdown]
# - **price:** precio de la vivienda.
# - **lotSize:** metros cuadrados de la vivienda.
# - **age:** antigüedad de la vivienda.
# - **landValue:** valor del terreno.
# - **livingArea:** metros cuadrados habitables.
# - **pctCollege:** porcentaje del vecindario con título universitario.
# - **bedrooms:** número de dormitorios.
# - **firplaces:** número de chimeneas.
# - **bathrooms:** número de cuartos de baño (el valor 0.5 hace referencia a cuartos de baño sin ducha).
# - **rooms:** número de habitaciones.
# - **heating:** tipo de calefacción.
# - **fuel:** tipo de alimentación de la calefacción (gas, electricidad o diesel).
# - **sewer:** tipo de desagüe.
# - **waterfront:** si la vivienda tiene vistas al lago.
# - **newConstruction:** si la vivienda es de nueva construcción.
# - **centralAir:** si la vivienda tiene aire acondicionado.

# %% [markdown]
# # **Instalando los módulos requeridos**

# %%
# !pip install sweetviz --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 80.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 💡 **Conceptos Clave sobre Sweetviz y Auto-EDA**
#
# **Auto-EDA (Análisis Exploratorio de Datos Automático)** es el proceso de utilizar herramientas de software para generar resúmenes estadísticos y visualizaciones completas de un conjunto de datos con un esfuerzo manual mínimo. Su principal ventaja es acelerar la fase inicial de comprensión de los datos.
#
# **Sweetviz** es una biblioteca de Python diseñada específicamente para este fin. Sus características más notables incluyen:
# - **Visualización de alta calidad:** Genera un archivo HTML interactivo e independiente con gráficos sumamente informativos y estética moderna.
# - **Comparación de conjuntos de datos:** Permite comparar fácilmente dos conjuntos de datos independientes (como entrenamiento y prueba) o subconjuntos basados en una variable categórica (como hombres vs. mujeres).
# - **Análisis del objetivo (Target Analysis):** Muestra de forma destacada cómo cada característica del conjunto de datos se correlaciona y se relaciona con la variable objetivo que deseamos predecir.
# - **Asociación mixta:** Calcula correlaciones numéricas (Pearson), relaciones numérico-categóricas (Razón de correlación) y asociaciones categóricas (Coeficiente de incertidumbre de Theil) automáticamente.
#
# ### **Funciones Clave:**
# 1. `sv.analyze(dataframe)`: Analiza un único DataFrame y genera el reporte estadístico completo.
# 2. `sv.compare([df1, "Nombre1"], [df2, "Nombre2"])`: Compara dos DataFrames (ej. entrenamiento vs. validación).
# 3. `sv.compare_intra(dataframe, dataframe["variable"] == valor, ["Grupo1", "Grupo2"])`: Compara dos subgrupos dentro de un mismo DataFrame.
# 4. `report.show_notebook()`: Renderiza el reporte directamente dentro de una celda del cuaderno Jupyter/Colab.

# %% [markdown]
# # **Carga de módulos**

# %% [markdown]
# ### **Para analisis de datos**

# %%
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/cristiandarioortegayubro/BA/main/Datasets/SaratogaHouses.csv"

# %%
datos = pd.read_csv(url)
datos.drop(columns="Unnamed: 0",inplace=True)
datos.head()
# Out:
#    precio  metros_totales  antiguedad  precio_terreno  metros_habitables  \
# 0  132500            0.09          42           50000                906
# 1  181115            0.92           0           22300               1953
# 2  109000            0.19         133            7300               1944
# 3  155000            0.41          13           18700               1944
# 4   86060            0.11           0           15000                840
#
#    universitarios  dormitorios  baños  habitaciones      calefaccion  \
# 0              35            2    1.0             5         electric
# 1              51            3    2.5             6  hot water/steam
# 2              51            4    1.0             8  hot water/steam
# 3              51            3    1.5             5          hot air
# 4              51            2    1.0             3          hot air
#
#   consumo_calefacion            desague vistas_lago nueva_construccion  \
# ...

# %% [markdown]
# ## **Para generación de reportes Auto EDA**

# %%
import sweetviz as sv

# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %% [markdown]
# # **Sweetviz**

# %% [markdown]
# # ***Generando el Reporte***

# %% [markdown]
# Parametros por defecto

# %%
report = sv.analyze(datos)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...
